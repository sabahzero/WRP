# %% [markdown]
# # Query WikiData to get Biomedical Entities
#
# We will get the nodes (and later some edges) for our biomedical graph from WikiData

# %% [markdown]
# ## Tues meet w/ Andrew
# - Research Notes
# - Run two codes in tandem, see how far you get with 02 of rephetio (similar or different?)

# %% [markdown]
# ## To Do
# 1. Is the script reproducible?
# 2. Automate reproduced script.
# 3. Does the script need improvements, now that's been reproduced?
# 4. Automate improved script.
# 5. Compare reproduced vs improved.
# 6. Test with other algorithms besides Rephetio, compare again with reproduced + improved.
# 7. Create web interface.
#
# - Include mechanisms such that libraries are transferrable, no matter who does it
# - Fix nodes where there's a time out (limit)
# - Check and include any differing nodes (for improved section)

# %%
import pandas as pd
from pathlib import Path

# 'ModuleNotFoundError' for both lines below
## Solution: pip install git+https://github.com/mmayers12/data_tools
### https://github.com/mmayers12/data_tools (fyi also a data_tools in pip, different)
#### so far, these work okay (there isn't a conflict)

from data_tools.df_processing import char_combine_iter 
from data_tools.wiki import node_query_pipeline

# New line recommended by notebook
from tqdm.autonotebook import tqdm
# Out:
# /Users/sulhasan/opt/anaconda3/lib/python3.8/site-packages/data_tools/df_processing.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
nodes = []

# %% [markdown]
# # Diseases

# %%
q = """SELECT DISTINCT ?disease ?diseaseLabel ?umlscui ?snomed_ct ?doid ?mesh ?mondo ?omim ?orpha
        WHERE {

          # Initial typing for Disease 
          # Either instance of Disease of has a Disease Ontology ID
          {?disease wdt:P31 wd:Q12136}UNION{?disease wdt:P699 ?doid}.

          OPTIONAL {?disease wdt:P2892 ?umlscui .}
          OPTIONAL {?disease wdt:P5806 ?snomed_ct. }
          OPTIONAL {?disease wdt:P699 ?doid. }
          OPTIONAL {?disease wdt:P486 ?mesh. }
          OPTIONAL {?disease wdt:P5270 ?mondo. }
          OPTIONAL {?disease wdt:P492 ?omim. }
          OPTIONAL {?disease wdt:P1550 ?orpha. }

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }"""

# %%
dis_curi_map = {'umlscui': 'UMLS', 'snomed_ct': 'SNOMED', 'mesh': 'MESH', 
                'doid': 'DOID', 'mondo': 'MONDO', 'omim': 'OMIM', 'orpha': 'ORPHA'}

res = node_query_pipeline(q, dis_curi_map, 'disease')
# what's happening in the 'node_query_pipeline()' function that's outputting format?
nodes.append(res)
nodes[0].head()
# Out:
#            id                                               name    label  \
# 0    Q1001150                                       fibrillation  Disease
# 1  Q100165995                       acute pulmonary hypertension  Disease
# 2    Q1002195  autosomal recessive limb-girdle muscular dystr...  Disease
# 3    Q1003534                                    bulbar syndrome  Disease
# 4    Q1004647                                 bullous pemphigoid  Disease
#
#                                                xrefs
# 0                                      UMLS:C0232197
# 1
# 2  DOID:DOID:0110297|MONDO:MONDO:0012248|OMIM:609...
# 3
# 4  DOID:DOID:8506|MESH:D010391|MONDO:MONDO:001908...

# %% [markdown]
# # Compounds

# %%
q = """SELECT DISTINCT ?compound ?compoundLabel ?kegg_drug ?chebi ?drugbank_id ?umlscui ?chembl_id ?unii ?ikey ?pubchem_cid ?rxnorm ?mesh_supplemental_record_ui ?mesh_descriptor_ui
        WHERE {

          # Initial typing for Compound
          # ?compound wdt:P31 wd:Q11173 .
          # Give me all Wikidata items where the item is an instance of a chemical compound

        # Whatever item up there may optionally have the following identifier + variable
          OPTIONAL { ?compound wdt:P665 ?kegg_drug .}
          OPTIONAL { ?compound wdt:P683 ?chebi .}
          OPTIONAL { ?compound wdt:P715 ?drugbank_id .}
          OPTIONAL { ?compound wdt:P2892 ?umlscui .}
          OPTIONAL { ?compound wdt:P592 ?chembl_id .}
          OPTIONAL { ?compound wdt:P652 ?unii .}
          OPTIONAL { ?compound wdt:P3350 ?ikey .}
          OPTIONAL { ?compound wdt:P662 ?pubchem_cid .}
          OPTIONAL { ?compound wdt:P3345 ?rxnorm .}
          OPTIONAL { ?compound wdt:P6680 ?mesh_supplemental_record_ui .}
          OPTIONAL { ?compound wdt:P486 ?mesh_descriptor_ui .}

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }
        
        limit 150000""" # limit needed here, fix later (266348 when Mike did it, but still less)
# max can be 150000 (changed from 200 to 150000)

# %% [markdown]
# 1201261 now
#
# SELECT (COUNT (DISTINCT ?compound) AS ?count)
#                         WHERE {
#
#           # Initial typing for Compound
#           ?compound wdt:P31 wd:Q11173 .
#
#            OPTIONAL { ?compound wdt:P665 ?kegg_drug .}
#            OPTIONAL { ?compound wdt:P683 ?chebi .}
#            OPTIONAL { ?compound wdt:P715 ?drugbank_id .}
#            OPTIONAL { ?compound wdt:P2892 ?umlscui .}
#            OPTIONAL { ?compound wdt:P592 ?chembl_id .}
#            OPTIONAL { ?compound wdt:P652 ?unii .}
#            OPTIONAL { ?compound wdt:P3350 ?ikey .}
#            OPTIONAL { ?compound wdt:P662 ?pubchem_cid .}
#            OPTIONAL { ?compound wdt:P3345 ?rxnorm .}
#            OPTIONAL { ?compound wdt:P6680 ?mesh_supplemental_record_ui .}
#            OPTIONAL { ?compound wdt:P486 ?mesh_descriptor_ui .}
#
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
#         }

# %%
chem_curi_map = {'unii': 'UNII', 
    'rxnorm': 'RxCUI', 
    'drugbank_id': 'DB', 
    'umlscui': 'UMLS', 
    'chebi': 'CHEBI', 
    'chembl_id': 'CHEMBL',
    'kegg_drug': 'KEGG', 
    'ikey': 'IKEY', 
    'pubchem_cid': 'PCID', 
    'mesh_supplemental_record_ui': 'MESH', 
    'mesh_descriptor_ui': 'MESH'}

res = node_query_pipeline(q, chem_curi_map, 'compound')
nodes.append(res)
nodes[1].head()

# JSONDecodeError is due to the time it takes
## Solution: Limit above (temporary fix)
# Out:
#          id                  name     label  \
# 0  Q1002152     fluoroiodomethane  Compound
# 1  Q1002165           fluticasone  Compound
# 2  Q1003185            fosfestrol  Compound
# 3  Q1003526  (S)-(+)-bulbocapnine  Compound
# 4  Q1007138            gabaculine  Compound
#
#                                                xrefs
# 0                                      PCID:13981373
# 1  CHEBI:5134|CHEMBL:CHEMBL1201396|KEGG:C07815|KE...
# 2  CHEBI:4532|CHEMBL:CHEMBL1200598|KEGG:C08145|KE...
# 3  CHEBI:3211|CHEMBL:CHEMBL157912|KEGG:C09367|PCI...
# 4         CHEBI:29585|CHEMBL:CHEMBL1394922|PCID:3445

# %% [markdown]
# # Phenotype

# %%
q = """SELECT DISTINCT ?phenotype ?phenotypeLabel ?hpo ?mesh ?omim ?snomed
        WHERE {

          # Initial typing for phenotype
          {?phenotype wdt:P31 wd:Q169872.}UNION{?phenotype wdt:P3841 ?hpo}

          # Xrefs associated with phenotypes
          OPTIONAL {?phenotype wdt:P3841 ?hpo .}
          OPTIONAL {?phenotype wdt:P486 ?mesh . }
          OPTIONAL {?phenotype wdt:P492 ?omim . }
          OPTIONAL {?phenotype wdt:P5806 ?snomed . }

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }"""

# %%
res = node_query_pipeline(q, {'mesh': 'MESH', 'omim': 'OMIM', 'hpo':'HP', 'snomed': 'SNOMED'}, 'phenotype')
nodes.append(res)
nodes[2].head()
# Out:
#            id                             name      label  \
# 0    Q1016605                 Burkitt lymphoma  Phenotype
# 1     Q101971                             wart  Phenotype
# 2  Q102187007             abnormal bowel sound  Phenotype
# 3  Q102187028                abdominal symptom  Phenotype
# 4  Q102293266  calcium oxalate nephrolithiasis  Phenotype
#
#                                  xrefs
# 0  HP:0030080|MESH:D002051|OMIM:113970
# 1              HP:0200043|MESH:D014860
# 2                           HP:0030142
# 3                           HP:0011458
# 4                           HP:0008672

# %% [markdown]
# # Gene
#
# Genes are too numerous and will require filtering to a single taxon in order for the query to finish successfully.
#
# For now we will only extract human genes, but in the future we will do the same for infectious taxa.

# %%
q = """SELECT DISTINCT ?gene ?geneLabel ?entrez ?symbol ?hgnc ?omim ?ensembl
        WHERE {{

          # Initial typing for Gene
          # ?gene wdt:P31 wd:Q7187.
          # ?gene wdt:P703 wd:{tax}.

          OPTIONAL{{?gene wdt:P351 ?entrez .}}
          OPTIONAL{{?gene wdt:P353 ?symbol .}}
          OPTIONAL{{?gene wdt:P354 ?hgnc .}}
          OPTIONAL{{?gene wdt:P492 ?omim .}}
          OPTIONAL{{?gene wdt:P594 ?ensembl .}}

          SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }}
        }}"""

human_tax_wd_id = 'Q15978631' 
q = q.format(tax=human_tax_wd_id)

# %%
gene_curi_map = {'entrez': 'NCBIGene', 'symbol': 'SYM', 'hgnc':'HGNC', 'omim':'OMIM', 'ensembl':'ENSG'}
res = node_query_pipeline(q, gene_curi_map, 'gene')
nodes.append(res)
nodes[3].head()
# Out:
#            id       name label  \
# 0    Q1022703   ZMPSTE24  Gene
# 1  Q106030625  MAP2K5-DT  Gene
# 2  Q106030627   CD2AP-DT  Gene
# 3  Q106030628   ERBIN-DT  Gene
# 4  Q106030629  PPP2CA-DT  Gene
#
#                                                xrefs
# 0  ENSG:ENSG00000084073|HGNC:12877|NCBIGene:10269...
# 1        HGNC:55261|NCBIGene:118732298|SYM:MAP2K5-DT
# 2         HGNC:55263|NCBIGene:118732299|SYM:CD2AP-DT
# 3         HGNC:55270|NCBIGene:118732300|SYM:ERBIN-DT
# 4        HGNC:55266|NCBIGene:118732304|SYM:PPP2CA-DT

# %% [markdown]
# # Protein

# %%
q = """SELECT DISTINCT ?protein ?proteinLabel ?uniprot
        WHERE {{

          # Initial typing for Protein
          # ?protein wdt:P31 wd:Q8054.
          # ?protein wdt:P703 wd:{tax}.

          OPTIONAL{{?protein wdt:P352 ?uniprot .}}
          SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }}
        }}"""
q = q.format(tax=human_tax_wd_id)

# %%
res = node_query_pipeline(q, {'uniprot':'UniProt'}, 'protein')
nodes.append(res)
nodes[4].head()
# Out:
#            id                                name    label           xrefs
# 0    Q1024612    C-X-C motif chemokine receptor 5  Protein  UniProt:P32302
# 1    Q1032902   Mucin 16, cell surface associated  Protein  UniProt:Q8WXI7
# 2  Q105362742            Neurotensin/neuromedin N  Protein  UniProt:P30990
# 3  Q105412156                          prepro-GRP  Protein  UniProt:P07492
# 4    Q1056532  CD44 molecule (Indian blood group)  Protein  UniProt:P16070

# %% [markdown]
# # Pathway

# %%
q = """SELECT DISTINCT ?pathway ?pathwayLabel ?react ?wpid
        WHERE {

          # Initial typing for Pathway
          # ?pathway wdt:P31 wd:Q4915012 .

          OPTIONAL{?pathway wdt:P3937 ?react .}
          OPTIONAL{?pathway wdt:P2410 ?wpid .}

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }"""

# %%
res = node_query_pipeline(q, {'react':'REACT', 'wpid':'WP'}, 'pathway')
nodes.append(res)
nodes[5].head()
# Out:
#            id                                               name    label  \
# 0  Q100166016         EML4 and NUDC in mitotic spindle formation  Pathway
# 1  Q100166017  Postmitotic nuclear pore complex (NPC) reforma...  Pathway
# 2  Q100166018  Sealing of the nuclear envelope (NE) by ESCRT-III  Pathway
# 3  Q100166022        Inhibition of DNA recombination at telomere  Pathway
# 4  Q100166036  Response of EIF2AK4 (GCN2) to amino acid defic...  Pathway
#
#                  xrefs
# 0  REACT:R-HSA-9648025
# 1  REACT:R-HSA-9615933
# 2  REACT:R-HSA-9668328
# 3  REACT:R-HSA-9670095
# 4  REACT:R-HSA-9633012

# %% [markdown]
# # Molecular Function

# %%
q = """SELECT DISTINCT ?molecular_function ?molecular_functionLabel ?goid
        WHERE {

          # Initial typing for molecular Function
          # ?molecular_function wdt:P31 wd:Q14860489 .
          # ?molecular_function wdt:P686 ?goid

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }"""

# %%
res = node_query_pipeline(q, {'goid':'GO'}, 'molecular_function')
nodes.append(res)
nodes[6].head()
# Out:
#           id                                      name               label  \
# 0   Q1012651                   ribonuclease P activity  Molecular Function
# 1  Q13667380                         metal ion binding  Molecular Function
# 2  Q13667398     lipoprotein particle receptor binding  Molecular Function
# 3  Q14326094  protein serine/threonine kinase activity  Molecular Function
# 4  Q14326101            serine-type peptidase activity  Molecular Function
#
#         xrefs
# 0  GO:0004526
# 1  GO:0046872
# 2  GO:0070325
# 3  GO:0004674
# 4  GO:0008236

# %% [markdown]
# # Biological Process

# %%
q = """SELECT DISTINCT ?biological_process ?biological_processLabel ?goid
        WHERE {

          # Initial typing for molecular Function
          # ?biological_process wdt:P31 wd:Q2996394 .
          # ?biological_process wdt:P686 ?goid

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }"""

# %%
res = node_query_pipeline(q, {'goid':'GO'}, 'biological_process')
nodes.append(res)
nodes[7].head()
# Out:
#           id                          name               label       xrefs
# 0  Q10344426                     pachytene  Biological Process  GO:0000239
# 1      Q1057                    metabolism  Biological Process  GO:0008152
# 2    Q105726                     urination  Biological Process  GO:0060073
# 3   Q1068809         cell cycle checkpoint  Biological Process  GO:0000075
# 4  Q10746904  intramembranous ossification  Biological Process  GO:0001957

# %% [markdown]
# # Cellular Component

# %%
q = """SELECT DISTINCT ?cellular_component ?cellular_componentLabel ?goid
    WHERE {

      # Initial typing for Cellular Component
      # ?cellular_component wdt:P31 wd:Q5058355 .
      # ?cellular_component wdt:P686 ?goid

      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
    }"""

# %%
res = node_query_pipeline(q, {'goid':'GO'}, 'cellular_component')
nodes.append(res)
nodes[8].head()
# Out:
#          id            name               label       xrefs
# 0  Q1051872         caveola  Cellular Component  GO:0005901
# 1  Q1053832  tight junction  Cellular Component  GO:0070160
# 2  Q1065756      melanosome  Cellular Component  GO:0042470
# 3  Q1134046     plasmodesma  Cellular Component  GO:0009506
# 4  Q1136436       costamere  Cellular Component  GO:0043034

# %% [markdown]
# # Anatomy

# %%
q = """SELECT DISTINCT ?anatomy ?anatomyLabel ?uberon ?mesh
        WHERE {

          # Anatomical Strucutres
          # ?anatomy wdt:P1554 ?uberon
          
          OPTIONAL{?anatomy wdt:P486 ?mesh .}

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }"""

# %%
res = node_query_pipeline(q, {'uberon':'UBERON', 'mesh': 'MESH'}, 'anatomy')
nodes.append(res)
nodes[9].head()
# Out:
#            id                                       name    label  \
# 0    Q1001337  mesencephalic nucleus of trigeminal nerve  Anatomy
# 1    Q1002789                posterior ethmoidal foramen  Anatomy
# 2    Q1003805                           Nucleus ambiguus  Anatomy
# 3     Q101004                                      aorta  Anatomy
# 4  Q102277188                      anatomical projection  Anatomy
#
#                          xrefs
# 0               UBERON:0001718
# 1               UBERON:0018654
# 2               UBERON:0001719
# 3  MESH:D001011|UBERON:0000947
# 4               UBERON:0004529

# %% [markdown]
# # Put them all together

# %%
nodes = pd.concat(nodes, sort=False, ignore_index=True)
len(nodes)
# Out:
# 301595

# %%
nodes['id'].nunique()
# Out:
# 300440

# %%
nodes[nodes['id'].duplicated(keep=False)].sort_values('id').head(50)
# Out:
#                 id                             name      label  \
# 15        Q1016605                 Burkitt lymphoma    Disease
# 165242    Q1016605                 Burkitt lymphoma  Phenotype
# 165243     Q101971                             wart  Phenotype
# 20         Q101971                             wart    Disease
# 66      Q102293266  calcium oxalate nephrolithiasis    Disease
# 165246  Q102293266  calcium oxalate nephrolithiasis  Phenotype
# 876       Q1027995                 pyloric stenosis    Disease
# 165247    Q1027995                 pyloric stenosis  Phenotype
# 165248   Q10282075            gingival fibromatosis  Phenotype
# 877      Q10282075            gingival fibromatosis    Disease
# 165249   Q10295763                   hyperlysinemia  Phenotype
# 882      Q10295763                   hyperlysinemia    Disease
# 899       Q1036696                      hypothermia    Disease
# 165256    Q1036696                      hypothermia  Phenotype
# 914      Q10434599                       bradyopsia    Disease
# 165257   Q10434599                       bradyopsia  Phenotype
# 922       Q1047559               agammaglobulinemia    Disease
# 165258    Q1047559               agammaglobulinemia  Phenotype
# 929       Q1049655                       paraplegia    Disease
# 165260    Q1049655                       paraplegia  Phenotype
# 930       Q1049881                    retinoschisis    Disease
# 165262    Q1049881                    retinoschisis  Phenotype
# 165265    Q1053824                  Raynaud disease  Phenotype
# 949       Q1053824                  Raynaud disease    Disease
# 954       Q1054718                   kidney disease    Disease
# 165266    Q1054718                   kidney disease  Phenotype
# 165268     Q105688                          hypoxia  Phenotype
# 961        Q105688                          hypoxia    Disease
# 976       Q1061988                      Flail chest    Disease
# 165273    Q1061988                      Flail chest  Phenotype
# 165276    Q1063085           neurogenic arthropathy  Phenotype
# 986       Q1063085           neurogenic arthropathy    Disease
# 165312    Q1068997                        cheilitis  Phenotype
# 1001      Q1068997                        cheilitis    Disease
# 1006      Q1071707       Arnold-Chiari malformation    Disease
# 165314    Q1071707       Arnold-Chiari malformation  Phenotype
# 165315    Q1072420        primary biliary cirrhosis  Phenotype
# 1008      Q1072420        primary biliary cirrhosis    Disease
# 1010      Q1072716                   Mongolian spot    Disease
# 165316    Q1072716                   Mongolian spot  Phenotype
# 1011     Q10748814                   megalencephaly    Disease
# 165317   Q10748814                   megalencephaly  Phenotype
# 165318    Q1075923                      cholestasis  Phenotype
# 1014      Q1075923                      cholestasis    Disease
# 165319    Q1076053                  chondroblastoma  Phenotype
# 1015      Q1076053                  chondroblastoma    Disease
# 165320    Q1076078                        chondroma  Phenotype
# 1018      Q1076078                        chondroma    Disease
# 165321    Q1076087                   chondrosarcoma  Phenotype
# 1020      Q1076087                   chondrosarcoma    Disease
#
#                                                     xrefs
# 15      DOID:DOID:8584|MESH:D002051|OMIM:113970|ORPHA:...
# 165242                HP:0030080|MESH:D002051|OMIM:113970
# 165243                            HP:0200043|MESH:D014860
# 20                             MESH:D014860|UMLS:C3665596
# 66                                      DOID:DOID:0080652
# 165246                                         HP:0008672
# 876            DOID:DOID:12639|MESH:D011707|UMLS:C0034194
# 165247                            HP:0002021|MESH:D011707
# 165248  HP:0000169|MESH:D005351|OMIM:135300|OMIM:60554...
# 877     DOID:DOID:0060466|MESH:D005351|MONDO:MONDO:001...
# 165249    HP:0002161|MESH:D020167|OMIM:238700|OMIM:238710
# 882     DOID:DOID:9274|MESH:D020167|OMIM:238700|OMIM:2...
# 899                            MESH:D007035|UMLS:C0020672
# 165256                            HP:0002045|MESH:D007035
# 914     DOID:DOID:0050335|MESH:C564243|MONDO:MONDO:001...
# 165257                HP:0030511|MESH:C564243|OMIM:608415
# 922     DOID:DOID:2583|MESH:D000361|MONDO:MONDO:001597...
# 165258  HP:0004313|HP:0004432|MESH:D000361|OMIM:601495...
# 929     DOID:DOID:607|MESH:D010264|MONDO:MONDO:0003757...
# 165260                            HP:0001258|MESH:D010264
# 930     DOID:DOID:8465|MESH:D041441|MONDO:MONDO:000457...
# 165262                HP:0030502|MESH:D041441|OMIM:312700
# 165265                HP:0030880|MESH:D011928|OMIM:179600
# 949     DOID:DOID:10300|MESH:D011928|OMIM:179600|UMLS:...
# 954     DOID:DOID:557|MESH:D007674|MONDO:MONDO:0005240...
# 165266                 HP:0000077|HP:0000112|MESH:D007674
# 165268                            HP:0012418|MESH:D000860
# 961                            MESH:D000860|UMLS:C0700292
# 976            MESH:D005409|SNOMED:78011002|UMLS:C0016196
# 165273            HP:0030207|MESH:D005409|SNOMED:78011002
# 165276            HP:0002821|MESH:D001177|SNOMED:67536000
# 986     DOID:DOID:14286|MESH:D001177|MONDO:MONDO:00019...
# 165312                            HP:0100825|MESH:D002613
# 1001    DOID:DOID:1762|MESH:D002613|MONDO:MONDO:000210...
# 1006    MESH:D001139|MONDO:MONDO:0000115|MONDO:MONDO:0...
# 165314                HP:0002308|MESH:D001139|OMIM:207950
# 165315  HP:0002613|MESH:D008105|OMIM:109720|OMIM:61300...
# 1008    DOID:DOID:12236|MESH:D008105|MONDO:MONDO:00053...
# 1010    DOID:DOID:4702|MESH:D049328|MONDO:MONDO:000658...
# 165316                            HP:0011369|MESH:D049328
# 1011    MESH:D058627|MONDO:MONDO:0007961|OMIM:155350|O...
# 165317                HP:0001355|MESH:D058627|OMIM:155350
# 165318                            HP:0001396|MESH:D002779
# 1014    DOID:DOID:13580|MESH:D002779|MONDO:MONDO:00017...
# 165319             HP:0030432|MESH:D002804|SNOMED:9001003
# 1015    DOID:DOID:2649|MESH:D002804|MONDO:MONDO:000499...
# 165320                            HP:0030038|MESH:D002812
# 1018    DOID:DOID:2602|MESH:D002812|MONDO:MONDO:000236...
# 165321                HP:0006765|MESH:D002813|OMIM:215300
# 1020    DOID:DOID:3371|MESH:D002813|MONDO:MONDO:000897...

# %%
nodes[nodes['id'].duplicated(keep=False)].sort_values('id').tail(50)
# Out:
#              id                         name      label  \
# 16442   Q947813             encephalomalacia    Disease
# 167207  Q947813             encephalomalacia  Phenotype
# 167208  Q950591                      scotoma  Phenotype
# 16447   Q950591                      scotoma    Disease
# 167209  Q950838                    germinoma  Phenotype
# 16448   Q950838                    germinoma    Disease
# 167210  Q954625     myelodysplastic syndrome  Phenotype
# 16452   Q954625     myelodysplastic syndrome    Disease
# 167211  Q954674       iron deficiency anemia  Phenotype
# 16453   Q954674       iron deficiency anemia    Disease
# 16454   Q954831                 prolactinoma    Disease
# 167212  Q954831                 prolactinoma  Phenotype
# 16455   Q955454                   Coxa valga    Disease
# 167213  Q955454                   Coxa valga  Phenotype
# 167214  Q957751        XY gonadal dysgenesis  Phenotype
# 16458   Q957751        XY gonadal dysgenesis    Disease
# 16459   Q958797                  scleroderma    Disease
# 167215  Q958797                  scleroderma  Phenotype
# 167217  Q961331               pilonidal cyst  Phenotype
# 16463   Q961331               pilonidal cyst    Disease
# 167227  Q964920           gingival recession  Phenotype
# 16468   Q964920           gingival recession    Disease
# 16469   Q966052               cryptorchidism    Disease
# 167228  Q966052               cryptorchidism  Phenotype
# 16475   Q970208                liver failure    Disease
# 167230  Q970208                liver failure  Phenotype
# 16490   Q972514               optic neuritis    Disease
# 167231  Q972514               optic neuritis  Phenotype
# 16491   Q973524            spondylolisthesis    Disease
# 167232  Q973524            spondylolisthesis  Phenotype
# 167233  Q974792                  albuminuria  Phenotype
# 16497   Q974792                  albuminuria    Disease
# 16498   Q974869                 leukocytosis    Disease
# 167234  Q974869                 leukocytosis  Phenotype
# 16501   Q975182          Pelger-Huet anomaly    Disease
# 167235  Q975182          Pelger-Huet anomaly  Phenotype
# 16502   Q975705  gastric mucosal hypertrophy    Disease
# 167236  Q975705  gastric mucosal hypertrophy  Phenotype
# 16503   Q976163               polyhydramnios    Disease
# 167237  Q976163               polyhydramnios  Phenotype
# 167238  Q976388               acute leukemia  Phenotype
# 16504   Q976388               acute leukemia    Disease
# 167239  Q977787           gallbladder cancer  Phenotype
# 16506   Q977787           gallbladder cancer    Disease
# 167240  Q979168               cerebral edema  Phenotype
# 16509   Q979168               cerebral edema    Disease
# 16527   Q994859               homocystinuria    Disease
# 167242  Q994859               homocystinuria  Phenotype
# 16528   Q994942                      bruxism    Disease
# 167243  Q994942                      bruxism  Phenotype
#
#                                                     xrefs
# 16442   DOID:DOID:2034|MESH:D004678|MONDO:MONDO:000674...
# 167207                            HP:0040197|MESH:D004678
# 167208                            HP:0000575|MESH:D012607
# 16447   DOID:DOID:9335|MESH:D012607|MONDO:MONDO:000475...
# 167209            HP:0100620|MESH:D018237|SNOMED:28307001
# 16448   DOID:DOID:3304|MESH:D018237|MONDO:MONDO:000259...
# 167210  HP:0002863|MESH:D009190|OMIM:614286|SNOMED:109...
# 16452   DOID:DOID:0050908|MESH:D009190|MONDO:MONDO:001...
# 167211                            HP:0001891|MESH:D018798
# 16453   DOID:DOID:11758|MESH:D018798|MONDO:MONDO:00013...
# 16454   DOID:DOID:5394|MESH:D015175|MONDO:MONDO:001091...
# 167212  HP:0006767|MESH:D015175|OMIM:600634|SNOMED:343...
# 16455            MESH:D060906|UMLS:C0239137|UMLS:C3549698
# 167213                            HP:0002673|MESH:D060906
# 167214  HP:0000037|MESH:D006061|OMIM:154230|OMIM:23342...
# 16458   DOID:DOID:14448|MESH:D006061|OMIM:154230|OMIM:...
# 16459   DOID:DOID:419|ORPHA:801|SNOMED:201441006|UMLS:...
# 167215                        HP:0100324|SNOMED:201441006
# 167217                HP:0010769|MESH:D010864|OMIM:173000
# 16463   MESH:D010864|MONDO:MONDO:0008249|OMIM:173000|U...
# 167227                            HP:0030816|MESH:D005889
# 16468   DOID:DOID:1134|MESH:D005889|UMLS:C0017572|UMLS...
# 16469   DOID:DOID:11383|MESH:D003456|MONDO:MONDO:00090...
# 167228                HP:0000028|MESH:D003456|OMIM:219050
# 16475          MESH:D017093|SNOMED:59927004|UMLS:C0085605
# 167230            HP:0001399|MESH:D017093|SNOMED:59927004
# 16490   DOID:DOID:1210|MESH:D009902|MONDO:MONDO:000588...
# 167231                 HP:0100653|HP:0100654|MESH:D009902
# 16491   DOID:DOID:6682|MESH:D013168|MONDO:MONDO:000847...
# 167232                HP:0003302|MESH:D013168|OMIM:184200
# 167233                            HP:0012592|MESH:D000419
# 16497                          MESH:D000419|UMLS:C0001925
# 16498                          MESH:D007964|UMLS:C0023518
# 167234                            HP:0001974|MESH:D007964
# 16501   DOID:DOID:9631|MESH:D010381|MONDO:MONDO:000821...
# 167235                HP:0011447|MESH:D010381|OMIM:169400
# 16502   DOID:DOID:8757|MESH:D005758|MONDO:MONDO:000765...
# 167236                HP:0005246|MESH:D005758|OMIM:137280
# 16503   DOID:DOID:8488|MESH:D006831|MONDO:MONDO:000458...
# 167237                            HP:0001561|MESH:D006831
# 167238                HP:0002488|MESH:C564112|OMIM:308960
# 16504   DOID:DOID:12603|MESH:C564112|MONDO:MONDO:00106...
# 167239                                         HP:0100575
# 16506   DOID:DOID:3121|MONDO:MONDO:0005411|UMLS:C00169...
# 167240                            HP:0002181|MESH:D001929
# 16509   DOID:DOID:4724|MESH:D001929|MONDO:MONDO:000668...
# 16527   DOID:DOID:9263|MESH:D006712|MONDO:MONDO:000473...
# 167242  HP:0002156|MESH:D006712|OMIM:236200|OMIM:23625...
# 16528   DOID:DOID:2846|MESH:D002012|MONDO:MONDO:000244...
# 167243                            HP:0003763|MESH:D002012

# %%
nodes['label'].value_counts()
# Out:
# Compound              148710
# Gene                   59061
# Biological Process     28674
# Protein                25476
# Disease                16532
# Molecular Function     11029
# Cellular Component      4155
# Pathway                 3389
# Anatomy                 2567
# Phenotype               2002
# Name: label, dtype: int64

# %% [markdown]
# ## Save

# %%
out_dir = Path('../results/')

# Make the output directory if doesn't already exist
out_dir.mkdir(parents=True, exist_ok=True)

nodes.to_csv(out_dir.joinpath('01a_nodes.csv'), index=False)

## edit 'pipeline' folder to be results?
