# %% [markdown]
# # Query WikiData to get Biomedical Entities
#
# We will get the nodes (and later some edges) for our biomedical graph from WikiData

# %% [markdown]
# ## To Do
# 1. Is the script reproducible?
# 2. Automate reproduced script.
# 3. Does the script need improvements, now that's been reproduced?
# 4. Automate improved script.
# 5. Compare reproduced vs improved.
# 6. Test with other algorithms besides Rephetio, compare again with reproduced + improved.
# 7. Create web interface.
#
# - Include mechanisms such that libraries are transferrable, no matter who does it
# - Fix nodes where there's a time out (limit)
# - Check and include any differing nodes (for improved section)

# %%
import pandas as pd
from pathlib import Path

# 'ModuleNotFoundError' for both lines below
## Solution: pip install git+https://github.com/mmayers12/data_tools
### https://github.com/mmayers12/data_tools (fyi also a data_tools in pip, different)
#### so far, these work okay (there isn't a conflict)

from data_tools.df_processing import char_combine_iter 
from data_tools.wiki import node_query_pipeline

# New line recommended by notebook
from tqdm.autonotebook import tqdm

# %%
nodes = []

# %% [markdown]
# # Diseases

# %%
q = """ SELECT DISTINCT ?disease ?diseaseLabel ?umlscui ?snomed_ct ?doid ?mesh ?mondo ?omim ?orpha
        WHERE {

          # Initial typing for Disease 
          # Either instance of Disease of has a Disease Ontology ID
          {?disease wdt:P31 wd:Q12136}UNION{?disease wdt:P699 ?doid}.

          OPTIONAL {?disease wdt:P2892 ?umlscui .}
          OPTIONAL {?disease wdt:P5806 ?snomed_ct. }
          OPTIONAL {?disease wdt:P699 ?doid. }
          OPTIONAL {?disease wdt:P486 ?mesh. }
          OPTIONAL {?disease wdt:P5270 ?mondo. }
          OPTIONAL {?disease wdt:P492 ?omim. }
          OPTIONAL {?disease wdt:P1550 ?orpha. }

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }"""

# %%
dis_curi_map = {'umlscui': 'UMLS', 'snomed_ct': 'SNOMED', 'mesh': 'MESH', 
                'doid': 'DOID', 'mondo': 'MONDO', 'omim': 'OMIM', 'orpha': 'ORPHA'}

res = node_query_pipeline(q, dis_curi_map, 'disease')
# what's happening in the 'node_query_pipeline()' function that's outputting format?
nodes.append(res)
nodes[0].head()
# Out:
#            id                                               name    label  \
# 0    Q1001150                                       fibrillation  Disease
# 1  Q100165995                       acute pulmonary hypertension  Disease
# 2    Q1002195  autosomal recessive limb-girdle muscular dystr...  Disease
# 3    Q1003534                                    bulbar syndrome  Disease
# 4    Q1004647                                 bullous pemphigoid  Disease
#
#                                                xrefs
# 0                                      UMLS:C0232197
# 1
# 2  DOID:DOID:0110297|MONDO:MONDO:0012248|OMIM:609...
# 3
# 4  DOID:DOID:8506|MESH:D010391|MONDO:MONDO:001908...

# %% [markdown]
# # Compounds

# %%
q = """SELECT DISTINCT ?compound ?compoundLabel ?kegg_drug ?chebi ?drugbank_id ?umlscui ?chembl_id ?unii ?ikey ?pubchem_cid ?rxnorm ?mesh_supplemental_record_ui ?mesh_descriptor_ui
        WHERE {

          # Initial typing for Compound
          # ?compound wdt:P31 wd:Q11173 .
          # Give me all Wikidata items where the item is an instance of a chemical compound

        # Whatever item up there may optionally have the following identifier + variable
          OPTIONAL { ?compound wdt:P665 ?kegg_drug .}
          OPTIONAL { ?compound wdt:P683 ?chebi .}
          OPTIONAL { ?compound wdt:P715 ?drugbank_id .}
          OPTIONAL { ?compound wdt:P2892 ?umlscui .}
          OPTIONAL { ?compound wdt:P592 ?chembl_id .}
          OPTIONAL { ?compound wdt:P652 ?unii .}
          OPTIONAL { ?compound wdt:P3350 ?ikey .}
          OPTIONAL { ?compound wdt:P662 ?pubchem_cid .}
          OPTIONAL { ?compound wdt:P3345 ?rxnorm .}
          OPTIONAL { ?compound wdt:P6680 ?mesh_supplemental_record_ui .}
          OPTIONAL { ?compound wdt:P486 ?mesh_descriptor_ui .}

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }
        
        limit 200""" # limit needed here, fix later

# %%
chem_curi_map = {'unii': 'UNII', 
    'rxnorm': 'RxCUI', 
    'drugbank_id': 'DB', 
    'umlscui': 'UMLS', 
    'chebi': 'CHEBI', 
    'chembl_id': 'CHEMBL',
    'kegg_drug': 'KEGG', 
    'ikey': 'IKEY', 
    'pubchem_cid': 'PCID', 
    'mesh_supplemental_record_ui': 'MESH', 
    'mesh_descriptor_ui': 'MESH'}

res = node_query_pipeline(q, chem_curi_map, 'compound')
nodes.append(res)
nodes[1].head()

# JSONDecodeError is due to the time it takes
## Solution: Limit 200 above (temporary fix)
# Out:
#            id                                               name    label  \
# 0    Q1001150                                       fibrillation  Disease
# 1  Q100165995                       acute pulmonary hypertension  Disease
# 2    Q1002195  autosomal recessive limb-girdle muscular dystr...  Disease
# 3    Q1003534                                    bulbar syndrome  Disease
# 4    Q1004647                                 bullous pemphigoid  Disease
#
#                                                xrefs
# 0                                      UMLS:C0232197
# 1
# 2  DOID:DOID:0110297|MONDO:MONDO:0012248|OMIM:609...
# 3
# 4  DOID:DOID:8506|MESH:D010391|MONDO:MONDO:001908...

# %% [markdown]
# # Phenotype

# %%
q = """SELECT DISTINCT ?phenotype ?phenotypeLabel ?hpo ?mesh ?omim ?snomed
        WHERE {

          # Initial typing for phenotype
          {?phenotype wdt:P31 wd:Q169872.}UNION{?phenotype wdt:P3841 ?hpo}

          # Xrefs associated with phenotypes
          OPTIONAL {?phenotype wdt:P3841 ?hpo .}
          OPTIONAL {?phenotype wdt:P486 ?mesh . }
          OPTIONAL {?phenotype wdt:P492 ?omim . }
          OPTIONAL {?phenotype wdt:P5806 ?snomed . }

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }"""

# %%
res = node_query_pipeline(q, {'mesh': 'MESH', 'omim': 'OMIM', 'hpo':'HP', 'snomed': 'SNOMED'}, 'phenotype')
nodes.append(res)
nodes[2].head()
# Out:
#         id         name     label  \
# 0  Q150717       decane  Compound
# 1  Q150731     undecane  Compound
# 2  Q150744     dodecane  Compound
# 3  Q150788    tridecane  Compound
# 4  Q150808  tetradecane  Compound
#
#                                                xrefs
# 0  CHEBI:41808|CHEMBL:CHEMBL134537|PCID:15600|UNI...
# 1  CHEBI:46342|CHEMBL:CHEMBL132474|PCID:14257|RxC...
# 2  CHEBI:28817|CHEMBL:CHEMBL30959|KEGG:C08374|MES...
# 3  CHEBI:35998|CHEMBL:CHEMBL135694|KEGG:C13834|PC...
# 4    CHEBI:41253|DB:03563|PCID:12389|UNII:03LY784Y58

# %% [markdown]
# # Gene
#
# Genes are too numerous and will require filtering to a single taxon in order for the query to finish successfully.
#
# For now we will only extract human genes, but in the future we will do the same for infectious taxa.

# %%
q = """SELECT DISTINCT ?gene ?geneLabel ?entrez ?symbol ?hgnc ?omim ?ensembl
        WHERE {{

          # Initial typing for Gene
          # ?gene wdt:P31 wd:Q7187.
          # ?gene wdt:P703 wd:{tax}.

          OPTIONAL{{?gene wdt:P351 ?entrez .}}
          OPTIONAL{{?gene wdt:P353 ?symbol .}}
          OPTIONAL{{?gene wdt:P354 ?hgnc .}}
          OPTIONAL{{?gene wdt:P492 ?omim .}}
          OPTIONAL{{?gene wdt:P594 ?ensembl .}}

          SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }}
        }}"""

human_tax_wd_id = 'Q15978631' 
q = q.format(tax=human_tax_wd_id)

# %%
gene_curi_map = {'entrez': 'NCBIGene', 'symbol': 'SYM', 'hgnc':'HGNC', 'omim':'OMIM', 'ensembl':'ENSG'}
res = node_query_pipeline(q, gene_curi_map, 'gene')
nodes.append(res)
nodes[3].head()
# Out:
#            id                             name      label  \
# 0    Q1016605                 Burkitt lymphoma  Phenotype
# 1     Q101971                             wart  Phenotype
# 2  Q102293266  calcium oxalate nephrolithiasis  Phenotype
# 3    Q1027995                 pyloric stenosis  Phenotype
# 4   Q10282075            gingival fibromatosis  Phenotype
#
#                                                xrefs
# 0                HP:0030080|MESH:D002051|OMIM:113970
# 1                            HP:0200043|MESH:D014860
# 2                                         HP:0008672
# 3                            HP:0002021|MESH:D011707
# 4  HP:0000169|MESH:D005351|OMIM:135300|OMIM:60554...

# %% [markdown]
# # Protein

# %%
q = """SELECT DISTINCT ?protein ?proteinLabel ?uniprot
        WHERE {{

          # Initial typing for Protein
          # ?protein wdt:P31 wd:Q8054.
          # ?protein wdt:P703 wd:{tax}.

          OPTIONAL{{?protein wdt:P352 ?uniprot .}}
          SERVICE wikibase:label {{ bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }}
        }}"""
q = q.format(tax=human_tax_wd_id)

# %%
res = node_query_pipeline(q, {'uniprot':'UniProt'}, 'protein')
nodes.append(res)
nodes[4].head()
# Out:
#            id       name label  \
# 0    Q1022703   ZMPSTE24  Gene
# 1  Q106030625  MAP2K5-DT  Gene
# 2  Q106030627   CD2AP-DT  Gene
# 3  Q106030628   ERBIN-DT  Gene
# 4  Q106030629  PPP2CA-DT  Gene
#
#                                                xrefs
# 0  ENSG:ENSG00000084073|HGNC:12877|NCBIGene:10269...
# 1        HGNC:55261|NCBIGene:118732298|SYM:MAP2K5-DT
# 2         HGNC:55263|NCBIGene:118732299|SYM:CD2AP-DT
# 3         HGNC:55270|NCBIGene:118732300|SYM:ERBIN-DT
# 4        HGNC:55266|NCBIGene:118732304|SYM:PPP2CA-DT

# %% [markdown]
# # Pathway

# %%
q = """SELECT DISTINCT ?pathway ?pathwayLabel ?react ?wpid
        WHERE {

          # Initial typing for Pathway
          # ?pathway wdt:P31 wd:Q4915012 .

          OPTIONAL{?pathway wdt:P3937 ?react .}
          OPTIONAL{?pathway wdt:P2410 ?wpid .}

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }"""

# %%
res = node_query_pipeline(q, {'react':'REACT', 'wpid':'WP'}, 'pathway')
nodes.append(res)
nodes[5].head()
# Out:
#         id              name     label  \
# 0  Q102769  sodium hydroxide  Compound
# 1  Q104219         bilirubin  Compound
# 2  Q104334     carbonic acid  Compound
# 3  Q105522         uric acid  Compound
# 4  Q107184    cupric sulfate  Compound
#
#                                                xrefs
# 0  CHEBI:32145|CHEMBL:CHEMBL2105794|DB:11151|KEGG...
# 1  CHEBI:16990|CHEMBL:CHEMBL501680|KEGG:C00486|ME...
# 2  CHEBI:28976|CHEMBL:CHEMBL1161632|KEGG:C01353|M...
# 3  CHEBI:17775|CHEMBL:CHEMBL792|DB:08844|KEGG:C00...
# 4  CHEBI:23414|DB:06778|KEGG:C18713|PCID:24462|UM...

# %% [markdown]
# # Molecular Function

# %%
q = """SELECT DISTINCT ?molecular_function ?molecular_functionLabel ?goid
        WHERE {

          # Initial typing for molecular Function
          # ?molecular_function wdt:P31 wd:Q14860489 .
          # ?molecular_function wdt:P686 ?goid

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }"""

# %%
res = node_query_pipeline(q, {'goid':'GO'}, 'molecular_function')
nodes.append(res)
nodes[6].head()
# Out:
#            id                                name    label           xrefs
# 0    Q1024612    C-X-C motif chemokine receptor 5  Protein  UniProt:P32302
# 1    Q1032902   Mucin 16, cell surface associated  Protein  UniProt:Q8WXI7
# 2  Q105362742            Neurotensin/neuromedin N  Protein  UniProt:P30990
# 3  Q105412156                          prepro-GRP  Protein  UniProt:P07492
# 4    Q1056532  CD44 molecule (Indian blood group)  Protein  UniProt:P16070

# %% [markdown]
# # Biological Process

# %%
q = """SELECT DISTINCT ?biological_process ?biological_processLabel ?goid
        WHERE {

          # Initial typing for molecular Function
          # ?biological_process wdt:P31 wd:Q2996394 .
          # ?biological_process wdt:P686 ?goid

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }"""

# %%
res = node_query_pipeline(q, {'goid':'GO'}, 'biological_process')
nodes.append(res)
nodes[7].head()
# Out:
#            id                                               name    label  \
# 0  Q100166016         EML4 and NUDC in mitotic spindle formation  Pathway
# 1  Q100166017  Postmitotic nuclear pore complex (NPC) reforma...  Pathway
# 2  Q100166018  Sealing of the nuclear envelope (NE) by ESCRT-III  Pathway
# 3  Q100166022        Inhibition of DNA recombination at telomere  Pathway
# 4  Q100166036  Response of EIF2AK4 (GCN2) to amino acid defic...  Pathway
#
#                  xrefs
# 0  REACT:R-HSA-9648025
# 1  REACT:R-HSA-9615933
# 2  REACT:R-HSA-9668328
# 3  REACT:R-HSA-9670095
# 4  REACT:R-HSA-9633012

# %% [markdown]
# # Cellular Component

# %%
q = """SELECT DISTINCT ?cellular_component ?cellular_componentLabel ?goid
    WHERE {

      # Initial typing for Cellular Component
      # ?cellular_component wdt:P31 wd:Q5058355 .
      # ?cellular_component wdt:P686 ?goid

      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
    }"""

# %%
res = node_query_pipeline(q, {'goid':'GO'}, 'cellular_component')
nodes.append(res)
nodes[8].head()
# Out:
#           id                                      name               label  \
# 0   Q1012651                   ribonuclease P activity  Molecular Function
# 1  Q13667380                         metal ion binding  Molecular Function
# 2  Q13667398     lipoprotein particle receptor binding  Molecular Function
# 3  Q14326094  protein serine/threonine kinase activity  Molecular Function
# 4  Q14326101            serine-type peptidase activity  Molecular Function
#
#         xrefs
# 0  GO:0004526
# 1  GO:0046872
# 2  GO:0070325
# 3  GO:0004674
# 4  GO:0008236

# %% [markdown]
# # Anatomy

# %%
q = """SELECT DISTINCT ?anatomy ?anatomyLabel ?uberon ?mesh
        WHERE {

          # Anatomical Strucutres
          # ?anatomy wdt:P1554 ?uberon
          
          OPTIONAL{?anatomy wdt:P486 ?mesh .}

          SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGAGE],en" }
        }"""

# %%
res = node_query_pipeline(q, {'uberon':'UBERON', 'mesh': 'MESH'}, 'anatomy')
nodes.append(res)
nodes[9].head()
# Out:
#           id                          name               label       xrefs
# 0  Q10344426                     pachytene  Biological Process  GO:0000239
# 1      Q1057                    metabolism  Biological Process  GO:0008152
# 2    Q105726                     urination  Biological Process  GO:0060073
# 3   Q1068809         cell cycle checkpoint  Biological Process  GO:0000075
# 4  Q10746904  intramembranous ossification  Biological Process  GO:0001957

# %% [markdown]
# # Put them all together

# %%
nodes = pd.concat(nodes, sort=False, ignore_index=True)
len(nodes)
# Out:
# 170010

# %%
nodes['id'].nunique()
# Out:
# 152182

# %%
nodes[nodes['id'].duplicated(keep=False)].sort_values('id').head(50)
# Out:
#                id                                               name  \
# 0        Q1001150                                       fibrillation
# 16682    Q1001150                                       fibrillation
# 16683  Q100165995                       acute pulmonary hypertension
# 1      Q100165995                       acute pulmonary hypertension
# 16684    Q1002195  autosomal recessive limb-girdle muscular dystr...
# 2        Q1002195  autosomal recessive limb-girdle muscular dystr...
# 16685    Q1003534                                    bulbar syndrome
# 3        Q1003534                                    bulbar syndrome
# 16686    Q1004647                                 bullous pemphigoid
# 4        Q1004647                                 bullous pemphigoid
# 5      Q100732653                                         Long COVID
# 16687  Q100732653                                         Long COVID
# 6      Q100973285                              mesenteric thrombosis
# 16688  Q100973285                              mesenteric thrombosis
# 16689  Q101244555                                    cuboid fracture
# 7      Q101244555                                    cuboid fracture
# 8      Q101245788                          dementia with Lewy bodies
# 16690  Q101245788                          dementia with Lewy bodies
# 16691  Q101534204   combined oxidative phosphorylation deficiency 33
# 9      Q101534204   combined oxidative phosphorylation deficiency 33
# 10     Q101541302                   pulmonary artery intimal sarcoma
# 16692  Q101541302                   pulmonary artery intimal sarcoma
# 11     Q101541613                        rectal small cell carcinoma
# 16693  Q101541613                        rectal small cell carcinoma
# 16694  Q101541672                                   CIC-DUX4 sarcoma
# 12     Q101541672                                   CIC-DUX4 sarcoma
# 13     Q101541689     colorectal large cell neuroendocrine carcinoma
# 16695  Q101541689     colorectal large cell neuroendocrine carcinoma
# 14       Q1016288                             buried bumper syndrome
# 16696    Q1016288                             buried bumper syndrome
# 16697    Q1016605                                   Burkitt lymphoma
# 33527    Q1016605                                   Burkitt lymphoma
# 15       Q1016605                                   Burkitt lymphoma
# 16       Q1017169                               Buruli ulcer disease
# 16698    Q1017169                               Buruli ulcer disease
# 17       Q1018534      progressive familial intrahepatic cholestasis
# 16699    Q1018534      progressive familial intrahepatic cholestasis
# 16700    Q1018652                                         byssinosis
# 18       Q1018652                                         byssinosis
# 19        Q101896                                          gonorrhea
# 16701     Q101896                                          gonorrhea
# 16702     Q101971                                               wart
# 33528     Q101971                                               wart
# 20        Q101971                                               wart
# 21       Q1019940                 Borjeson-Forssman-Lehmann syndrome
# 16703    Q1019940                 Borjeson-Forssman-Lehmann syndrome
# 22       Q1020201                                      Böök syndrome
# 16704    Q1020201                                      Böök syndrome
# 16705    Q1022312                                         C syndrome
# 23       Q1022312                                         C syndrome
#
#            label                                              xrefs
# 0        Disease                                      UMLS:C0232197
# 16682    Disease                                      UMLS:C0232197
# 16683    Disease
# 1        Disease
# 16684    Disease  DOID:DOID:0110297|MONDO:MONDO:0012248|OMIM:609...
# 2        Disease  DOID:DOID:0110297|MONDO:MONDO:0012248|OMIM:609...
# 16685    Disease
# 3        Disease
# 16686    Disease  DOID:DOID:8506|MESH:D010391|MONDO:MONDO:001908...
# 4        Disease  DOID:DOID:8506|MESH:D010391|MONDO:MONDO:001908...
# 5        Disease
# 16687    Disease
# 6        Disease
# 16688    Disease
# 16689    Disease
# 7        Disease
# 8        Disease
# 16690    Disease
# 16691    Disease                      DOID:DOID:0111495|OMIM:617713
# 9        Disease                      DOID:DOID:0111495|OMIM:617713
# 10       Disease
# 16692    Disease
# 11       Disease
# 16693    Disease
# 16694    Disease
# 12       Disease
# 13       Disease
# 16695    Disease
# 14       Disease                                      UMLS:C2242690
# 16696    Disease                                      UMLS:C2242690
# 16697    Disease  DOID:DOID:8584|MESH:D002051|OMIM:113970|ORPHA:...
# 33527  Phenotype                HP:0030080|MESH:D002051|OMIM:113970
# 15       Disease  DOID:DOID:8584|MESH:D002051|OMIM:113970|ORPHA:...
# 16       Disease  DOID:DOID:0050456|MESH:D054312|MONDO:MONDO:000...
# 16698    Disease  DOID:DOID:0050456|MESH:D054312|MONDO:MONDO:000...
# 17       Disease  DOID:DOID:0070221|OMIM:211600|ORPHA:172|UMLS:C...
# 16699    Disease  DOID:DOID:0070221|OMIM:211600|ORPHA:172|UMLS:C...
# 16700    Disease   DOID:DOID:10323|MESH:D002095|MONDO:MONDO:0006688
# 18       Disease   DOID:DOID:10323|MESH:D002095|MONDO:MONDO:0006688
# 19       Disease          DOID:DOID:7551|MESH:D006069|UMLS:C0018081
# 16701    Disease          DOID:DOID:7551|MESH:D006069|UMLS:C0018081
# 16702    Disease                         MESH:D014860|UMLS:C3665596
# 33528  Phenotype                            HP:0200043|MESH:D014860
# 20       Disease                         MESH:D014860|UMLS:C3665596
# 21       Disease  DOID:DOID:0050681|MESH:C536575|MONDO:MONDO:001...
# 16703    Disease  DOID:DOID:0050681|MESH:C536575|MONDO:MONDO:001...
# 22       Disease  MESH:C562993|MONDO:MONDO:0007207|OMIM:112300|O...
# 16704    Disease  MESH:C562993|MONDO:MONDO:0007207|OMIM:112300|O...
# 16705    Disease  DOID:DOID:0111581|MESH:C537418|MONDO:MONDO:000...
# 23       Disease  DOID:DOID:0111581|MESH:C537418|MONDO:MONDO:000...

# %%
nodes[nodes['id'].duplicated(keep=False)].sort_values('id').tail(50)
# Out:
#               id                               name      label  \
# 16658    Q979168                     cerebral edema    Disease
# 33340    Q979168                     cerebral edema    Disease
# 33341    Q980709                 status epilepticus    Disease
# 16659    Q980709                 status epilepticus    Disease
# 16660  Q98078318                       bone sarcoma    Disease
# 33342  Q98078318                       bone sarcoma    Disease
# 16661    Q980926                       polymyositis    Disease
# 33343    Q980926                       polymyositis    Disease
# 16662  Q98266891             Shrunken pore syndrome    Disease
# 33344  Q98266891             Shrunken pore syndrome    Disease
# 16663  Q98404923  acute respiratory tract infection    Disease
# 33345  Q98404923  acute respiratory tract infection    Disease
# 16664  Q98483463                Highlander Syndrome    Disease
# 33346  Q98483463                Highlander Syndrome    Disease
# 33347  Q98608770       smoking-related lung disease    Disease
# 16665  Q98608770       smoking-related lung disease    Disease
# 16666  Q98688207   primary bladder neck obstruction    Disease
# 33348  Q98688207   primary bladder neck obstruction    Disease
# 16667    Q987319             secondary hypertension    Disease
# 33349    Q987319             secondary hypertension    Disease
# 33350  Q98831372                     dental fistula    Disease
# 16668  Q98831372                     dental fistula    Disease
# 16669    Q988405             essential hypertension    Disease
# 33351    Q988405             essential hypertension    Disease
# 33352  Q98844836               hematologic disorder    Disease
# 16670  Q98844836               hematologic disorder    Disease
# 16671  Q98960925         Pasteurellaceae infections    Disease
# 33353  Q98960925         Pasteurellaceae infections    Disease
# 33354    Q991023     Brown's tendon sheath syndrome    Disease
# 16672    Q991023     Brown's tendon sheath syndrome    Disease
# 33355    Q991538                 pituitary apoplexy    Disease
# 16673    Q991538                 pituitary apoplexy    Disease
# 33356    Q991897                           sacbrood    Disease
# 16674    Q991897                           sacbrood    Disease
# 33357    Q992139    human granulocytic anaplasmosis    Disease
# 16675    Q992139    human granulocytic anaplasmosis    Disease
# 16676    Q994794                               noma    Disease
# 33358    Q994794                               noma    Disease
# 35482    Q994859                     homocystinuria  Phenotype
# 16677    Q994859                     homocystinuria    Disease
# 33359    Q994859                     homocystinuria    Disease
# 16678    Q994942                            bruxism    Disease
# 33360    Q994942                            bruxism    Disease
# 35483    Q994942                            bruxism  Phenotype
# 33361  Q99547700                          Q99547700    Disease
# 16679  Q99547700                          Q99547700    Disease
# 16680  Q99726018                          Q99726018    Disease
# 33362  Q99726018                          Q99726018    Disease
# 33363    Q998273         Smith-Lemli-Opitz syndrome    Disease
# 16681    Q998273         Smith-Lemli-Opitz syndrome    Disease
#
#                                                    xrefs
# 16658  DOID:DOID:4724|MESH:D001929|MONDO:MONDO:000668...
# 33340  DOID:DOID:4724|MESH:D001929|MONDO:MONDO:000668...
# 33341          DOID:DOID:1824|MESH:D013226|UMLS:C0038220
# 16659          DOID:DOID:1824|MESH:D013226|UMLS:C0038220
# 16660                                  DOID:DOID:0080639
# 33342                                  DOID:DOID:0080639
# 16661  MESH:D017285|MONDO:MONDO:0019127|ORPHA:732|UML...
# 33343  MESH:D017285|MONDO:MONDO:0019127|ORPHA:732|UML...
# 16662
# 33344
# 16663                                      UMLS:C1442786
# 33345                                      UMLS:C1442786
# 16664
# 33346
# 33347
# 16665
# 16666                                      UMLS:C0266337
# 33348                                      UMLS:C0266337
# 16667  DOID:DOID:11130|MONDO:MONDO:0001200|UMLS:C0155616
# 33349  DOID:DOID:11130|MONDO:MONDO:0001200|UMLS:C0155616
# 33350                                       MESH:D003751
# 16668                                       MESH:D003751
# 16669  DOID:DOID:10825|MESH:D000075222|MONDO:MONDO:00...
# 33351  DOID:DOID:10825|MESH:D000075222|MONDO:MONDO:00...
# 33352
# 16670
# 16671                                       MESH:D016871
# 33353                                       MESH:D016871
# 33354  DOID:DOID:10235|MONDO:MONDO:0014624|OMIM:61640...
# 16672  DOID:DOID:10235|MONDO:MONDO:0014624|OMIM:61640...
# 33355  DOID:DOID:1129|MESH:D010899|MONDO:MONDO:000690...
# 16673  DOID:DOID:1129|MESH:D010899|MONDO:MONDO:000690...
# 33356
# 16674
# 33357              DOID:DOID:0050025|MONDO:MONDO:0005118
# 16675              DOID:DOID:0050025|MONDO:MONDO:0005118
# 16676  DOID:DOID:9672|MESH:D009625|MONDO:MONDO:001712...
# 33358  DOID:DOID:9672|MESH:D009625|MONDO:MONDO:001712...
# 35482  HP:0002156|MESH:D006712|OMIM:236200|OMIM:23625...
# 16677  DOID:DOID:9263|MESH:D006712|MONDO:MONDO:000473...
# 33359  DOID:DOID:9263|MESH:D006712|MONDO:MONDO:000473...
# 16678  DOID:DOID:2846|MESH:D002012|MONDO:MONDO:000244...
# 33360  DOID:DOID:2846|MESH:D002012|MONDO:MONDO:000244...
# 35483                            HP:0003763|MESH:D002012
# 33361
# 16679
# 16680
# 33362
# 33363  DOID:DOID:14692|MESH:D019082|MONDO:MONDO:00100...
# 16681  DOID:DOID:14692|MESH:D019082|MONDO:MONDO:00100...

# %%
nodes['label'].value_counts()
# Out:
# Gene                  59058
# Disease               33364
# Biological Process    28674
# Protein               25477
# Molecular Function    11029
# Cellular Component     4155
# Pathway                3386
# Anatomy                2568
# Phenotype              1957
# Compound                342
# Name: label, dtype: int64

# %% [markdown]
# ## Save

# %%
this_name = '01a_WikiData_Nodes'
out_dir = Path('../2_pipeline/').joinpath(this_name, 'out')

# Make the output directory if doesn't already exist
out_dir.mkdir(parents=True, exist_ok=True)

nodes.to_csv(out_dir.joinpath('nodes.csv'), index=False)

## edit 'pipeline' folder to be results?
