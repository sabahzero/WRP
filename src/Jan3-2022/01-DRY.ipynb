# %% [markdown]
# ### Python Code Review
# - Overview of code and its application (eLife paper)
# - nodes.csv; Edits to current for loop, and converting over 3 other loops to be more 'DRY' <br>One loop possibly becoming a function
# - Folder conversion

# %% [markdown]
# ### To Do (in order of when they show up)
#
# - Warning (reading mike's CSVs)
# - NaN: qualifier and inner1
# - Make time stamp into a for loop
# - Why are categories much less than for WDumper and wdsub?
# - Why is 'Chemical Hazard' empty?
# - NaN in the 'name' section of some CSVs

# %%
# comparison of no grep
import pandas as pd

import time 
from datetime import datetime

import os

# %%
nodes_mike = pd.read_csv('file-examples/nodes_2019-09-03.csv')  
edges_mike = pd.read_csv('file-examples/edges_2019-09-03.csv')
# Out:
# /Users/sulhasan/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
nodes_mike.head()
# Out:
#         :ID    :LABEL               name
# 0  Q4735440  Compound            alpidem
# 1  Q5983577  Compound        ibacitabine
# 2   Q221174  Compound         topiramate
# 3  Q2016367  Compound  tetraphenylborate
# 4   Q168685  Compound     fentin acetate

# %%
edges_mike.head() # qualifier NaN (both head and tail)
# Out:
#   :START_ID  :END_ID                              :TYPE qualifier inner1
# 0   Q144085  Q412496  SIGNIFICANT_DRUG_INTERACTION_CdiC       NaN    NaN
# 1  Q3712521  Q419394  SIGNIFICANT_DRUG_INTERACTION_CdiC       NaN    NaN
# 2   Q410061  Q417597  SIGNIFICANT_DRUG_INTERACTION_CdiC       NaN    NaN
# 3   Q174259    Q7739  SIGNIFICANT_DRUG_INTERACTION_CdiC       NaN    NaN
# 4  Q3791612   Q41576  SIGNIFICANT_DRUG_INTERACTION_CdiC       NaN    NaN

# %%
edges_mike.tail()
# Out:
#         :START_ID    :END_ID              :TYPE qualifier     inner1
# 614760  Q21112306  Q14878358  UP_REGULATES_GuBP       NaN  Q14761970
# 614761  Q21111886  Q14864067  UP_REGULATES_GuBP       NaN  Q14863719
# 614762  Q11705457  Q14864067  UP_REGULATES_GuBP       NaN  Q14863719
# 614763    Q423701  Q14878358  UP_REGULATES_GuBP       NaN  Q14761970
# 614764   Q3616234  Q14878358  UP_REGULATES_GuBP       NaN  Q14761970

# %%
# Time stamp

timeStringNow = datetime.now().strftime("+%Y-%m-%dT00:00:00Z") 

start_time = time.time()
activesite = pd.read_json('files/activesite.ndjson', lines=True) 
end_time = time.time()
print((end_time - start_time)/60, "for activesite.ndjson")
# Out:
# 0.0008685986200968424 for activesite.ndjson

# %%
# Create time stamp
timeStringNow = datetime.now().strftime("+%Y-%m-%dT00:00:00Z") 

start_time = time.time()
activesite = pd.read_json('files/activesite.ndjson', lines=True) 
end_time = time.time()
print((end_time - start_time)/60, "for activesite.ndjson") 

start_time = time.time()
anatomy = pd.read_json('files/anatomy.ndjson', lines=True) 
end_time = time.time()
print((end_time - start_time)/60, "for anatomy.ndjson") 

start_time = time.time()
biologicalpathway = pd.read_json('files/biologicalpathway.ndjson', lines=True) 
end_time = time.time()
print((end_time - start_time)/60, "for biologicalpathway.ndjson") 

start_time = time.time()
biologicalprocess = pd.read_json('files/biologicalprocess.ndjson', lines=True) 
end_time = time.time()
print((end_time - start_time)/60, "for biologicalprocess.ndjson")

start_time = time.time()
bindingsite = pd.read_json('files/bindingsite.ndjson', lines=True) 
end_time = time.time()
print((end_time - start_time)/60, "for bindingsite.ndjson")

start_time = time.time()
cellularcomponent = pd.read_json('files/cellularcomponent.ndjson', lines=True) 
end_time = time.time()
print((end_time - start_time)/60, "for cellularcomponent.ndjson")

start_time = time.time()
chemicalhazard = pd.read_json('files/chemicalhazard.ndjson', lines=True) 
end_time = time.time()
print((end_time - start_time)/60, "for chemicalhazard.ndjson") 

start_time = time.time()
compound = pd.read_json('files/compound.ndjson', lines=True) 
end_time = time.time()
print((end_time - start_time)/60, "for compound.ndjson")

start_time = time.time()
disease = pd.read_json('files/disease.ndjson', lines=True) 
end_time = time.time()
print((end_time - start_time)/60, "for disease.ndjson")

start_time = time.time()
gene = pd.read_json('files/gene.ndjson', lines=True) 
end_time = time.time()
print((end_time - start_time)/60, "for gene.ndjson") # 2 min

start_time = time.time()
medicalspecialty = pd.read_json('files/medicalspecialty.ndjson', lines=True) 
end_time = time.time()
print((end_time - start_time)/60, "for medicalspecialty.ndjson") 

start_time = time.time()
molecularfunction = pd.read_json('files/molecularfunction.ndjson', lines=True) 
end_time = time.time()
print((end_time - start_time)/60, "for molecularfunction.ndjson")

start_time = time.time()
protein = pd.read_json('files/protein.ndjson', lines=True) 
end_time = time.time()
print((end_time - start_time)/60, "for protein.ndjson") # 12 min

start_time = time.time()
proteindomain = pd.read_json('files/proteindomain.ndjson', lines=True) 
end_time = time.time()
print((end_time - start_time)/60, "for proteindomain.ndjson")

start_time = time.time()
proteinfamily = pd.read_json('files/proteinfamily.ndjson', lines=True) 
end_time = time.time()
print((end_time - start_time)/60, "for proteinfamily.ndjson")

start_time = time.time()
sequencevariant = pd.read_json('files/sequencevariant.ndjson', lines=True) 
end_time = time.time()
print((end_time - start_time)/60, "for sequencevariant.ndjson")

start_time = time.time()
structuralmotif = pd.read_json('files/structuralmotif.ndjson', lines=True) 
end_time = time.time()
print((end_time - start_time)/60, "for structuralmotif.ndjson")

start_time = time.time()
symptom = pd.read_json('files/symptom.ndjson', lines=True) 
end_time = time.time()
print((end_time - start_time)/60, "for symptom.ndjson")
# Out:
# 0.0002136826515197754 for activesite.ndjson
# 0.0028772830963134767 for anatomy.ndjson
# 0.0011151631673177083 for biologicalpathway.ndjson
# 0.01685828367869059 for biologicalprocess.ndjson
# 0.00015334685643513996 for bindingsite.ndjson
# 0.004989516735076904 for cellularcomponent.ndjson
# 4.881223042805989e-05 for chemicalhazard.ndjson
# 0.2749996503194173 for compound.ndjson
# 0.00136488676071167 for disease.ndjson
# 10.554157332579296 for gene.ndjson
# 0.005231932799021403 for medicalspecialty.ndjson
# 0.05962743361790975 for molecularfunction.ndjson
# 63.00341316461563 for protein.ndjson
# 0.005757097403208415 for proteindomain.ndjson
# 0.0073135972023010256 for proteinfamily.ndjson
# 0.0003326535224914551 for sequencevariant.ndjson
# 0.00011376539866129558 for structuralmotif.ndjson
# 0.00019429922103881837 for symptom.ndjson

# %%
directory = 'files-test'
    
node_dict = []    
    
for filename in os.listdir(directory):
    
    f = os.path.join(directory, filename)
    timeStringNow = datetime.now().strftime("+%Y-%m-%dT00:00:00Z") 
    
    if os.path.isfile(f):
        start_time = time.time()
        
        node_name = [*.ndjson]
        node_dict[node_name] = pd.read_json(f, lines=True)

        end_time = time.time()
        print((end_time - start_time)/60, "for", f) # How do I remove the 'files/' ?
   

activesite = pd.read_json('files/activesite.ndjson', lines=True)  

# create a dictionary with the keys that have part of the file name   
# values be data

content.tail()
# Out:
#   File "<ipython-input-6-cf5d1c3a1ac1>", line 13
#     node_name = [*.ndjson]
#                   ^
# SyntaxError: invalid syntax

# %%
filename = "/a/b/c/d/.ndjson"
print(os.path.basename(filename))
print(os.path.basename(filename).strip(".ndjson"))

node_dict={}
node_dict[node_name]="my pandas object"
for key, values in node_dict.items(
print(key,values))
# Out:
# .ndjson

# %%
nodes_mike[':LABEL'].value_counts() # 19 categories
# Out:
# Biological Process           24718
# Gene                         23737
# Protein Family               10406
# Compound                      8557
# Disease                       8302
# Protein Domain                5230
# Molecular Function            4397
# Biological Pathway            2461
# Sequence Variant              1835
# Cellular Component            1785
# Chemical Hazard                687
# Super-Secondary Structure      663
# Chemical Role                  499
# Symptom                        228
# Anatomical Structure           218
# Active Site                    114
# Structural Motif               109
# Medical Specialty               69
# Binding Site                    69
# Name: :LABEL, dtype: int64

# %%
# Convert to for loop

print( "Biological Process \t", len(biologicalprocess)) 
print( "Gene \t\t\t", len(gene)) 
print( "Protein Family \t\t", len(proteinfamily)) 
print( "Compound \t\t", len(compound))
print( "Disease \t\t", len(disease))
print( "Protein Domain \t\t", len(proteindomain))
print( "Molecular Function \t", len(molecularfunction))
print( "Biological Pathway \t", len(biologicalpathway))
print( "Sequence Variant \t", len(sequencevariant))
print( "Cellular Component \t", len(cellularcomponent))
print( "Chemical Hazard \t", len(chemicalhazard))
print( "Anatomical Structure \t", len(anatomy))
print( "Active Site \t\t", len(activesite))
print( "Structural Motif \t", len(structuralmotif))
print( "Binding Site \t\t", len(bindingsite))
print( "Medical Specialty \t", len(medicalspecialty))
print( "\nProtein \t\t", len(protein))
# Out:
# Biological Process 	 3562
# Gene 			 89348
# Protein Family 		 2441
# Compound 		 18718
# Disease 		 337
# Protein Domain 		 1117
# Molecular Function 	 1307
# Biological Pathway 	 52
# Sequence Variant 	 80
# Cellular Component 	 511
# Chemical Hazard 	 0
# Anatomical Structure 	 368
# Active Site 		 9
# Structural Motif 	 35
# Binding Site 		 10
# Medical Specialty 	 24
#
# Protein 		 63604

# %%
import csv

# %%
# Write as function and create into for loop?

with open('activesite.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID#', ':LABEL#', 'name'])
    for index, row in activesite.iterrows():
        if "en" in row["descriptions"].keys():
            print(row["id"]+"#Active Site#"+row["descriptions"]["en"]["value"], file = file)
        else:
            print(row["id"]+"#Active Site#", file = file)
activesitefinal = pd.read_csv('activesite.csv', sep="#")

with open('anatomy.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID#', ':LABEL#', 'name'])
    for index, row in anatomy.iterrows():
        if "en" in row["descriptions"].keys():
            print(row["id"]+"#Anatomical Structure#"+row["descriptions"]["en"]["value"], file = file)
        else:
            print(row["id"]+"#Anatomical Structure#", file = file)
anatomyfinal = pd.read_csv('anatomy.csv', sep="#")

with open('biologicalpathway.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID#', ':LABEL#', 'name'])
    for index, row in biologicalpathway.iterrows():
        if "en" in row["descriptions"].keys():
            print(row["id"]+"#Biological Pathway#"+row["descriptions"]["en"]["value"], file = file)
        else:
            print(row["id"]+"#Biological Pathway#", file = file)
biologicalpathwayfinal = pd.read_csv('biologicalpathway.csv', sep="#")

with open('biologicalprocess.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID#', ':LABEL#', 'name'])
    for index, row in biologicalprocess.iterrows():
        if "en" in row["descriptions"].keys():
            print(row["id"]+"#Biological Process#"+row["descriptions"]["en"]["value"], file = file)
        else:
            print(row["id"]+"#Biological Process#", file = file)
biologicalprocessfinal = pd.read_csv('biologicalprocess.csv', sep="#")

with open('bindingsite.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID#', ':LABEL#', 'name'])
    for index, row in bindingsite.iterrows():
        if "en" in row["descriptions"].keys():
            print(row["id"]+"#Binding Site#"+row["descriptions"]["en"]["value"], file = file)
        else:
            print(row["id"]+"#Binding Site#", file = file)
bindingsitefinal = pd.read_csv('bindingsite.csv', sep="#")

with open('cellularcomponent.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID#', ':LABEL#', 'name'])
    for index, row in cellularcomponent.iterrows():
        if "en" in row["descriptions"].keys():
            print(row["id"]+"#Cellular Component#"+row["descriptions"]["en"]["value"], file = file)
        else:
            print(row["id"]+"#Cellular Component#", file = file)
cellularcomponentfinal = pd.read_csv('cellularcomponent.csv', sep="#")

with open('chemicalhazard.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID#', ':LABEL#', 'name'])
    for index, row in chemicalhazard.iterrows():
        if "en" in row["descriptions"].keys():
            print(row["id"]+"#Chemical Hazard#"+row["descriptions"]["en"]["value"], file = file)
        else:
            print(row["id"]+"#Chemical Hazard#", file = file)
chemicalhazardfinal = pd.read_csv('chemicalhazard.csv', sep="#")

with open('compound.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID#', ':LABEL#', 'name'])
    for index, row in compound.iterrows():
        if "en" in row["descriptions"].keys():
            print(row["id"]+"#Compound#"+row["descriptions"]["en"]["value"], file = file)
        else:
            print(row["id"]+"#Compound#", file = file)
compoundfinal = pd.read_csv('compound.csv', sep="#")

with open('disease.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID#', ':LABEL#', 'name'])
    for index, row in disease.iterrows():
        if "en" in row["descriptions"].keys():
            print(row["id"]+"#Disease#"+row["descriptions"]["en"]["value"], file = file)
        else:
            print(row["id"]+"#Disease#", file = file)
diseasefinal = pd.read_csv('disease.csv', sep="#")

with open('gene.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID#', ':LABEL#', 'name'])
    for index, row in gene.iterrows():
        if "en" in row["descriptions"].keys():
            print(row["id"]+"#Gene#"+row["descriptions"]["en"]["value"], file = file)
        else:
            print(row["id"]+"#Gene#", file = file)
genefinal = pd.read_csv('gene.csv', sep="#")

with open('medicalspecialty.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID#', ':LABEL#', 'name'])
    for index, row in medicalspecialty.iterrows():
        if "en" in row["descriptions"].keys():
            print(row["id"]+"#Medical Specialty#"+row["descriptions"]["en"]["value"], file = file)
        else:
            print(row["id"]+"#Medical Specialty#", file = file)
medicalspecialtyfinal = pd.read_csv('medicalspecialty.csv', sep="#")

with open('molecularfunction.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID#', ':LABEL#', 'name'])
    for index, row in molecularfunction.iterrows():
        if "en" in row["descriptions"].keys():
            print(row["id"]+"#Molecular Function#"+row["descriptions"]["en"]["value"], file = file)
        else:
            print(row["id"]+"#Molecular Function#", file = file)
molecularfunctionfinal = pd.read_csv('molecularfunction.csv', sep="#")

with open('protein.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID#', ':LABEL#', 'name'])
    for index, row in protein.iterrows():
        if "en" in row["descriptions"].keys():
            print(row["id"]+"#Protein#"+row["descriptions"]["en"]["value"], file = file)
        else:
            print(row["id"]+"#Protein#", file = file)
proteinfinal = pd.read_csv('protein.csv', sep="#")

with open('proteindomain.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID#', ':LABEL#', 'name'])
    for index, row in proteindomain.iterrows():
        if "en" in row["descriptions"].keys():
            print(row["id"]+"#Protein Domain#"+row["descriptions"]["en"]["value"], file = file)
        else:
            print(row["id"]+"#Protein Domain#", file = file)
proteindomainfinal = pd.read_csv('proteindomain.csv', sep="#")

with open('proteinfamily.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID#', ':LABEL#', 'name'])
    for index, row in proteinfamily.iterrows():
        if "en" in row["descriptions"].keys():
            print(row["id"]+"#Protein Family#"+row["descriptions"]["en"]["value"], file = file)
        else:
            print(row["id"]+"#Protein Family#", file = file)
proteinfamilyfinal = pd.read_csv('proteinfamily.csv', sep="#")

with open('sequencevariant.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID#', ':LABEL#', 'name'])
    for index, row in sequencevariant.iterrows():
        if "en" in row["descriptions"].keys():
            print(row["id"]+"#Sequence Variant#"+row["descriptions"]["en"]["value"], file = file)
        else:
            print(row["id"]+"#Sequence Variant#", file = file)
sequencevariantfinal = pd.read_csv('sequencevariant.csv', sep="#")

with open('structuralmotif.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID#', ':LABEL#', 'name'])
    for index, row in structuralmotif.iterrows():
        if "en" in row["descriptions"].keys():
            print(row["id"]+"#Structural Motif#"+row["descriptions"]["en"]["value"], file = file)
        else:
            print(row["id"]+"#Structural Motif#", file = file)
structuralmotiffinal = pd.read_csv('structuralmotif.csv', sep="#")

with open('symptom.csv', 'w') as file:  
    writer = csv.writer(file)
    writer.writerow([':ID#', ':LABEL#', 'name'])
    for index, row in symptom.iterrows():
        if "en" in row["descriptions"].keys():
            print(row["id"]+"#Symptom#"+row["descriptions"]["en"]["value"], file = file)
        else:
            print(row["id"]+"#Symptom#", file = file)
symptomfinal = pd.read_csv('symptom.csv', sep="#")

print(activesitefinal.head(3))
print(anatomyfinal.head(3))
print(biologicalpathwayfinal.head(3))
print(biologicalprocessfinal.head(3))
print(bindingsitefinal.head(3))
print(cellularcomponentfinal.head(3))
print(chemicalhazardfinal.head(3))
print(compoundfinal.head(3))
print(diseasefinal.head(3))
print(genefinal.head(3))
print(medicalspecialtyfinal.head(3))
print(molecularfunctionfinal.head(3))
print(proteinfinal.head(3))
print(proteindomainfinal.head(3))
print(proteinfamilyfinal.head(3))
print(sequencevariantfinal.head(3))
print(structuralmotiffinal.head(3))
print(symptomfinal.head(3))
# Out:
#          :ID      ,:LABEL                 ,name
# 0  Q24721060  Active Site  InterPro Active Site
# 1  Q24721301  Active Site  InterPro Active Site
# 2  Q24721995  Active Site  InterPro Active Site
#      :ID               ,:LABEL  \
# 0  Q7365  Anatomical Structure
# 1  Q9377  Anatomical Structure
# 2  Q9609  Anatomical Structure
#
#                                                ,name
# 0                 contractile soft tissue of mammals
# 1  internal organ in most animals, including vert...
# 2  blood vessel that carry deoxygenated blood tow...
#          :ID             ,:LABEL  \
# 0  Q21694734  Biological Pathway
# 1  Q28031274  Biological Pathway
# 2  Q29891990  Biological Pathway
#
#                                                ,name
# 0                                  metabolic pathway
# 1  Glycolysis is the metabolic pathway that conve...
# 2  The mitogen-activated protein kinase (MAPK) ca...
#        :ID             ,:LABEL  \
# 0    Q1057  Biological Process
# ...

# %%
# convert into for loop

# make sure same number of columns (1:3)
activesitefinal = activesitefinal[[':ID', ',:LABEL', ',name']]
anatomyfinal = anatomyfinal[[':ID', ',:LABEL', ',name']]
biologicalpathwayfinal = biologicalpathwayfinal[[':ID', ',:LABEL', ',name']]
biologicalprocessfinal = biologicalprocessfinal[[':ID', ',:LABEL', ',name']]
bindingsitefinal = bindingsitefinal[[':ID', ',:LABEL', ',name']]
cellularcomponentfinal = cellularcomponentfinal[[':ID', ',:LABEL', ',name']]
chemicalhazardfinal = chemicalhazardfinal[[':ID', ',:LABEL', ',name']]
compoundfinal = compoundfinal[[':ID', ',:LABEL', ',name']]
diseasefinal = diseasefinal[[':ID', ',:LABEL', ',name']]
genefinal = genefinal[[':ID', ',:LABEL', ',name']]
medicalspecialtyfinal = medicalspecialtyfinal[[':ID', ',:LABEL', ',name']]
molecularfunctionfinal = molecularfunctionfinal[[':ID', ',:LABEL', ',name']]
proteinfinal = proteinfinal[[':ID', ',:LABEL', ',name']]
proteindomainfinal = proteindomainfinal[[':ID', ',:LABEL', ',name']]
proteinfamilyfinal = proteinfamilyfinal[[':ID', ',:LABEL', ',name']]
sequencevariantfinal = sequencevariantfinal[[':ID', ',:LABEL', ',name']]
structuralmotiffinal = structuralmotiffinal[[':ID', ',:LABEL', ',name']]
symptomfinal = symptomfinal[[':ID', ',:LABEL', ',name']]

nodes = pd.concat([activesitefinal, anatomyfinal, biologicalpathwayfinal, 
                   biologicalprocessfinal, bindingsitefinal, cellularcomponentfinal,
                   chemicalhazardfinal, compoundfinal, diseasefinal, 
                   genefinal, medicalspecialtyfinal, molecularfunctionfinal, 
                   proteinfinal, proteindomainfinal, proteinfamilyfinal, 
                   sequencevariantfinal, structuralmotiffinal, symptomfinal], axis=0)
nodes.to_csv('nodes.csv')

# %%
# files.ndjson
# files.csv

# 1 [this approach]
## Move all *.csv files => files-new
## setwd files-new => concat to nodes.csv

# Does directory exist? If not, make directory
# Then, move all files to new folder

# 2
## Move all *.csv files EXCEPT for nodes.csv => files-new

if not os.path.exists("files-new"):
    os.mkdir("files-new")
    
for  filename in os.listdir('.')

# %%
# move all with .csv (that's not nodes.csv) to another folder within

## import os
## import shutil

### src_dir = "/Users/sulhasan/Desktop/Project/WRP/src/Jan3-2022"
### dst_dir = "/Users/sulhasan/Desktop/Project/WRP/src/Jan3-2022/files-new"

### for root, dirs, files in os.walk(src_dir):
#    for f in files:
#        if f.endswith('.csv'):
#            shutil.copy(os.path.join(root,f), dst_dir)
