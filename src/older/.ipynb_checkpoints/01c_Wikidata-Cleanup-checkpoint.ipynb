# %% [markdown]
# This notebook clears up duplicate node and edge types resultant from the data output (two .csv files) of the previous notebook.
#
#
# I. [Load Packages](#Load) [clicking on phrase will take you directly to section] <br>
# II. [Clean-up Nodes File](#Nodes) <br>
#
# <br>
# III. [Mapping Edges to Node Types](#Map)<br>
# IV. [Concatenate and View Updated Node and Edge Results, Save as .csv files](#Concatenate) <br>

# %% [markdown]
# ## Load
# Packages and modules with relevant functions

# %%
import pandas as pd

import time 
from datetime import datetime

from pathlib import Path
from tqdm.autonotebook import tqdm

from data_tools import combine_nodes_and_edges
from data_tools.df_processing import combine_group_cols_on_char, split_col
from data_tools.wiki import xref_to_wd_item, get_curi_xrefs
from data_tools.plotting import count_plot_h

# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %%
prev_dir = Path('../results/').resolve()
nodes = pd.read_csv(prev_dir.joinpath('01b_nodes.csv'), dtype=str)
edges = pd.read_csv(prev_dir.joinpath('01b_edges.csv'), dtype=str)

# %%
drop_idx = []
new_nodes = []
new_edges = []

# %% [markdown]
# ## Nodes
# Clean-up of 01b_nodes.csv

# %%
duped_ids = nodes[nodes['id'].duplicated(keep=False)].sort_values('id')
duped_ids['id'].nunique() # 253849 *check that this matches with 1a vs 1b
# Out:
# 218821

# %%
dup_type_map = duped_ids.groupby('id')['label'].apply(lambda x: ', '.join(sorted(list(x)))).to_dict()
duped_ids['duped_types'] = duped_ids['id'].map(dup_type_map)

# %%
dup_frac = duped_ids['duped_types'].value_counts() / duped_ids['duped_types'].value_counts().max()

# %%
dt = (duped_ids['duped_types'].value_counts() # Maintains a consistent ordering
                              .to_frame()
                              .reset_index()
                              .sort_values(['duped_types', 'index'], ascending=(True, True))['index']
                              .tolist())

dt = ['Anatomy, Disease', 
      'Cellular Component, Phenotype', 
      'Disease, Gene', 
      'Disease, Taxon',
      'Anatomy, Phenotype',
      'Compound, Gene',
      'Biological Process, Phenotype',
      'Anatomy, Cellular Component',
      'Biological Process, Disease',
      'Compound, Protein',
      'Biological Process, Molecular Function',
      'Biological Process, Pathway',
      'Disease, Phenotype']

print(dt[0:13]) # Check that all show
# Out:
# ['Anatomy, Disease', 'Cellular Component, Phenotype', 'Disease, Gene', 'Disease, Taxon', 'Anatomy, Phenotype', 'Compound, Gene', 'Biological Process, Phenotype', 'Anatomy, Cellular Component', 'Biological Process, Disease', 'Compound, Protein', 'Biological Process, Molecular Function', 'Biological Process, Pathway', 'Disease, Phenotype']

# %%
dti = iter(dt) # Re-save as dti

# %%
# Add more documentation later

this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')

# No show for these, why? 
## Working after increasing limit on compounds -- maybe there weren't connections?
### More compounds mean more likely to show up as duplicate
### How to classify if something is a disease vs phenotype, and how to compute
#### If everything is assigned as Disease (Disease, Phenotype) ==> if we flip, do we get same downstream result in algorithm?
##### If different, then look into (biologically, contextually) metric for what's better?
# Out:
#               id                           name    label           xrefs  \
# 642672  Q7170418  persistent pupillary membrane  Anatomy  UBERON:0002269
# 706996  Q7170418  persistent pupillary membrane  Disease   UMLS:C0344541
#
#              duped_types
# 642672  Anatomy, Disease
# 706996  Anatomy, Disease

# %% [markdown]
# This is a Disease, but it is located in anatomy...

# %%
# shows now, xrefs are needed to help identify duplicates across labels

xid = duped_ids.query('duped_types == @this_dup and label == "Anatomy"')['xrefs'].values[0]
qid = xref_to_wd_item(nodes, xid, always_list=True)
nodes.query('id in @qid')
# Out:
#               id                           name    label           xrefs
# 642672  Q7170418  persistent pupillary membrane  Anatomy  UBERON:0002269
# 706996  Q7170418  persistent pupillary membrane  Disease   UMLS:C0344541

# %% [markdown]
# No other WD items have that UBERON identifier. Drop the Anatomy, but add a new edge

# %%
def xrefs_to_new_nodes(combined_nodes, new_names=None):
    add_nodes = combined_nodes[['xrefs', 'name', 'label']].rename(columns={'xrefs': 'id'}).copy()
    if new_names is not None:
        add_nodes['name'] = new_names
    return add_nodes
    
def xrefs_to_new_edges(combined_nodes, start_col, end_col, semmantics):
    # ensure we've got a dataframe (single index will return series)
    if type(combined_nodes) == pd.Series:
        combined_nodes = combined_nodes.to_frame().T
    
    add_edges = combined_nodes[['xrefs', 'id']].rename(columns={start_col: 'start_id', end_col: 'end_id'}).copy()
    add_edges['type'] = semmantics
    add_edges['dsrc_type'] = 'computed'
    add_edges['comp_type'] = 'split'
    return add_edges.loc[:, ['start_id','end_id','type','dsrc_type','comp_type']]

# %%
def combine_xrefs_and_set_label(combined_nodes, label):
    add_nodes = combine_group_cols_on_char(combined_nodes, ['id'], ['xrefs'], prog=False)
    add_nodes['label'] = label
    add_nodes = add_nodes.drop('duped_types', axis=1)
    return add_nodes

# %%
# Prepare to drop the bad edge
to_drop = [duped_ids.query('duped_types == @this_dup and label == "Anatomy"').index.values[0]]
drop_idx += to_drop

# Add the new node
add_node = xrefs_to_new_nodes(duped_ids.loc[to_drop], 'Pupillary membrane')
new_nodes.append(add_node)

# And add the edge
add_edge = xrefs_to_new_edges(duped_ids.loc[to_drop], 'id', 'xrefs', 'localized_to')
new_edges.append(add_edge)

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#              id                    name               label  \
# 772346  Q767442  neurofibrillary tangle           Phenotype
# 675528  Q767442  neurofibrillary tangle  Cellular Component
#
#                              xrefs                    duped_types
# 772346  HP:HP:0002185|MESH:D016874  Cellular Component, Phenotype
# 675528                  GO:0097418  Cellular Component, Phenotype

# %% [markdown]
# While a valid phenotype, seems ot have more incommon with the cell component...

# %%
this_drop = duped_ids.query('duped_types == @this_dup').index.tolist()
drop_idx += this_drop
new_nodes.append(combine_xrefs_and_set_label(duped_ids.loc[this_drop], 'Cellular Component'))

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#                id name    label  \
# 708902  Q14913011  MVK     Gene
# 693182  Q14913011  MVK  Disease
#
#                                                     xrefs    duped_types
# 708902  ENSG:ENSG00000110921|HGNC:7530|NCBIGene:4598|O...  Disease, Gene
# 693182  MONDO:0012481|OMIM:175900|OMIM:251170|OMIM:260...  Disease, Gene

# %% [markdown]
# This is a Gene... look for this MONDO ID elsewhere...

# %%
xid = duped_ids.query('duped_types == @this_dup and label == "Disease"')['xrefs'].values[0]
xid = [x for x in xid.split('|') if x.startswith('MONDO:')][0]
mondo_ids = xref_to_wd_item(nodes, xid, always_list=True)
nodes.query('id in @mondo_ids')

# xid -- need xrefs afterall (need to go back and update)
# Out:
#                id                name    label  \
# 693182  Q14913011                 MVK  Disease
# 701227   Q3043158  mevalonic aciduria  Disease
# 708902  Q14913011                 MVK     Gene
#
#                                                     xrefs
# 693182  MONDO:0012481|OMIM:175900|OMIM:251170|OMIM:260...
# 701227  DOID:DOID:0050452|MESH:D054078|MONDO:0012481|O...
# 708902  ENSG:ENSG00000110921|HGNC:7530|NCBIGene:4598|O...

# %% [markdown]
# The Disease already exists, prepare to drop and ensure that the edge between the two exists

# %%
to_drop = duped_ids.query('duped_types == @this_dup and label == "Disease"').index.values[0]
drop_idx.append(to_drop)

sid, eid = nodes.query('id in @mondo_ids')['id'].unique()
edges.query('(start_id == @sid and end_id == @eid) or (start_id == @eid and end_id == @sid)')
# Out:
#          start_id    end_id             type      dsrc_type comp_type
# 680618  Q14913011  Q3043158  associated_with  crowd_sourced       NaN

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#              id                            name    label  \
# 693999  Q184627  human papillomavirus infection  Disease
# 114     Q184627  human papillomavirus infection    Taxon
#
#                                                     xrefs     duped_types
# 693999  DOID:DOID:11166|MONDO:0005161|SNOMED:240532009...  Disease, Taxon
# 114                                                   NaN  Disease, Taxon

# %% [markdown]
# HPV infection is not a taxon, but rather a disease. It has a cause of ... hpv

# %%
drop_idx += duped_ids.query('duped_types == @this_dup and label == "Taxon"').index.tolist()

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#               id                name      label                        xrefs  \
# 770651  Q1174313            Diastema  Phenotype   HP:HP:0000699|MESH:D003970
# 640681  Q1174313            Diastema    Anatomy  MESH:D003970|UBERON:0012111
# 771702   Q356002  anterior pituitary  Phenotype   HP:HP:0010625|MESH:D010903
# 641721   Q356002  anterior pituitary    Anatomy  MESH:D010903|UBERON:0002196
#
#                duped_types
# 770651  Anatomy, Phenotype
# 640681  Anatomy, Phenotype
# 771702  Anatomy, Phenotype
# 641721  Anatomy, Phenotype

# %% [markdown]
# Both well annotated, but seeming more like anatomy nodes... will keep the xrefs

# %%
this_drop = duped_ids.query('duped_types == @this_dup').index.tolist()
drop_idx += this_drop
new_nodes.append(combine_xrefs_and_set_label(duped_ids.loc[this_drop], 'Anatomy'))

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#              id name     label  \
# 683756  Q418553  NGB  Compound
# 766001  Q418553  NGB      Gene
#
#                                                     xrefs     duped_types
# 683756                                                NaN  Compound, Gene
# 766001  ENSG:ENSG00000165553|HGNC:14077|NCBIGene:58157...  Compound, Gene

# %% [markdown]
# Two compounds with no xrefs... Just drop the compound version

# %%
drop_idx = drop_idx + duped_ids.query('duped_types == @this_dup and label == "Compound"').index.tolist()

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#                id                     name               label  \
# 644376  Q14864096  skeletal muscle atrophy  Biological Process
# 770815  Q14864096  skeletal muscle atrophy           Phenotype
# 647851  Q15322281      chromosome breakage  Biological Process
# 770845  Q15322281      chromosome breakage           Phenotype
# 670784     Q35831                    sleep  Biological Process
# 771708     Q35831                    sleep           Phenotype
#
#                              xrefs                    duped_types
# 644376                  GO:0014732  Biological Process, Phenotype
# 770815               HP:HP:0003202  Biological Process, Phenotype
# 647851                  GO:0031052  Biological Process, Phenotype
# 770845  HP:HP:0003220|MESH:D019457  Biological Process, Phenotype
# 670784                  GO:0030431  Biological Process, Phenotype
# 771708  HP:HP:0002329|MESH:D012890  Biological Process, Phenotype

# %% [markdown]
# Phenotypes and biological Processes... GO is a really tight annotaiton system, so don't really want to remove... will keep the pheno annotations...

# %%
this_drop = duped_ids.query('duped_types == @this_dup').index.tolist()
drop_idx += this_drop
new_nodes.append(combine_xrefs_and_set_label(duped_ids.loc[this_drop], 'Biological Process'))

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#               id                    name               label  \
# 675361  Q4736445          climbing fiber  Cellular Component
# 641972  Q4736445          climbing fiber             Anatomy
# 675531   Q776995  neuromuscular junction  Cellular Component
# 642853   Q776995  neuromuscular junction             Anatomy
#
#                               xrefs                  duped_types
# 675361                   GO:0044301  Anatomy, Cellular Component
# 641972               UBERON:2002185  Anatomy, Cellular Component
# 675531                   GO:0031594  Anatomy, Cellular Component
# 642853  MESH:D009469|UBERON:0001029  Anatomy, Cellular Component

# %% [markdown]
# These are all Cell Component Terms... `myelin` and `climbing fiber` have proper uberon annotations, but the remainder are either xref'd to a (close but) incorrect term, or xref to obsolete UBERON terms.

# %%
# Get rid of the conflicting nodes
this_drop = duped_ids.query('duped_types == @this_dup and label == "Anatomy"').index.tolist()
drop_idx = drop_idx + this_drop

# Keep the two ok nodes
keep_xrefs = duped_ids.loc[this_drop].query('name in {!r}'.format(['myelin', 'climbing fiber']))
add_nodes = xrefs_to_new_nodes(keep_xrefs)
new_nodes.append(add_nodes)

# Add links between the two concepts
add_edges = xrefs_to_new_edges(keep_xrefs, 'id', 'xrefs', 'localized_to')
new_edges.append(add_edge)

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#               id                       name               label  \
# 671265  Q5898315  type III hypersensitivity  Biological Process
# 705915  Q5898315  type III hypersensitivity             Disease
# 705944  Q5958765           hypersensitivity             Disease
# 671267  Q5958765           hypersensitivity  Biological Process
# 707406  Q7860879   type IV hypersensitivity             Disease
# 671409  Q7860879   type IV hypersensitivity  Biological Process
#
#                                                     xrefs  \
# 671265                                         GO:0001802
# 705915  DOID:DOID:1557|MESH:D007105|MONDO:0007004|UMLS...
# 705944  DOID:DOID:0060056|MESH:D006967|MONDO:0000605|U...
# 671267                                         GO:0002524
# 707406          DOID:DOID:2916|MESH:D006968|UMLS:C0021070
# 671409                                         GO:0001806
#
#                         duped_types
# 671265  Biological Process, Disease
# 705915  Biological Process, Disease
# 705944  Biological Process, Disease
# 671267  Biological Process, Disease
# 707406  Biological Process, Disease
# 671409  Biological Process, Disease

# %% [markdown]
# Definitely instances of both.. need to split into Biological Processes and Diseases

# %%
this_drop = duped_ids.query('duped_types == @this_dup and label == "Biological Process"').index.tolist()
drop_idx = drop_idx + this_drop

new_nodes.append(xrefs_to_new_nodes(duped_ids.loc[this_drop]))
new_edges.append(xrefs_to_new_edges(duped_ids.loc[this_drop], 'xrefs', 'id', 'causes'))

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#              id      name     label  \
# 677598  Q170617  glucagon  Compound
# 772658  Q170617  glucagon   Protein
#
#                                                     xrefs        duped_types
# 677598  CHEBI:5391|CHEMBL:CHEMBL266481|DB:00040|KEGG:C...  Compound, Protein
# 772658                                                NaN  Compound, Protein

# %% [markdown]
# These are all Polypeptides... However, they have numerous chemical annotations...

# %%
this_drop = duped_ids.query('duped_types == @this_dup').index.tolist()
drop_idx += this_drop
new_nodes.append(combine_xrefs_and_set_label(duped_ids.loc[this_drop], 'Protein'))

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#                id                     name               label       xrefs  \
# 798090  Q14820641  protein kinase activity  Molecular Function  GO:0004672
# 643557  Q14820641  protein kinase activity  Biological Process  GO:0004672
#
#                                    duped_types
# 798090  Biological Process, Molecular Function
# 643557  Biological Process, Molecular Function

# %% [markdown]
# These are all obsolete terms. Drop em all.

# %%
drop_idx = drop_idx + duped_ids.query('duped_types == @this_dup').index.tolist()

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#                id                                   name               label  \
# 767418  Q14859896  cellular amino acid metabolic process             Pathway
# 643802  Q14859896  cellular amino acid metabolic process  Biological Process
# 767419  Q14864262              protein metabolic process             Pathway
# 644436  Q14864262              protein metabolic process  Biological Process
# 767420  Q14866112            apoptotic signaling pathway             Pathway
# 645014  Q14866112            apoptotic signaling pathway  Biological Process
# 670284   Q2792936                       lipid metabolism  Biological Process
# 767424   Q2792936                       lipid metabolism             Pathway
# 770337   Q5768379                        hippo signaling             Pathway
# 671249   Q5768379                        hippo signaling  Biological Process
# 671425     Q84230                              secretion  Biological Process
# 770434     Q84230                              secretion             Pathway
#
#              xrefs                  duped_types
# 767418         NaN  Biological Process, Pathway
# 643802  GO:0006520  Biological Process, Pathway
# 767419         NaN  Biological Process, Pathway
# 644436  GO:0019538  Biological Process, Pathway
# 767420         NaN  Biological Process, Pathway
# 645014  GO:0097190  Biological Process, Pathway
# 670284  GO:0006629  Biological Process, Pathway
# 767424         NaN  Biological Process, Pathway
# 770337         NaN  Biological Process, Pathway
# 671249  GO:0035329  Biological Process, Pathway
# 671425  GO:0046903  Biological Process, Pathway
# 770434         NaN  Biological Process, Pathway

# %% [markdown]
# These pathways have no Xrefs, so we will keep them as GO biological Processes.

# %%
qr = duped_ids.query('duped_types == @this_dup')
drop_idx = drop_idx + qr[qr['xrefs'].isnull()].index.tolist()

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#                 id                             name      label  \
# 691564    Q1016605                 Burkitt lymphoma    Disease
# 770492    Q1016605                 Burkitt lymphoma  Phenotype
# 770493     Q101971                             wart  Phenotype
# 691569     Q101971                             wart    Disease
# 770496  Q102293266  calcium oxalate nephrolithiasis  Phenotype
# ...            ...                              ...        ...
# 772503     Q979168                   cerebral edema  Phenotype
# 772505     Q994859                   homocystinuria  Phenotype
# 707945     Q994859                   homocystinuria    Disease
# 772506     Q994942                          bruxism  Phenotype
# 707946     Q994942                          bruxism    Disease
#
#                                                     xrefs         duped_types
# 691564  DOID:DOID:8584|MESH:D002051|OMIM:113970|ORPHA:...  Disease, Phenotype
# 770492             HP:HP:0030080|MESH:D002051|OMIM:113970  Disease, Phenotype
# 770493                         HP:HP:0200043|MESH:D014860  Disease, Phenotype
# 691569                         MESH:D014860|UMLS:C3665596  Disease, Phenotype
# 770496                                      HP:HP:0008672  Disease, Phenotype
# ...                                                   ...                 ...
# 772503                         HP:HP:0002181|MESH:D001929  Disease, Phenotype
# 772505  HP:HP:0002156|MESH:D006712|OMIM:236200|OMIM:23...  Disease, Phenotype
# 707945  DOID:DOID:9263|MESH:D006712|MONDO:0004737|OMIM...  Disease, Phenotype
# 772506                         HP:HP:0003763|MESH:D002012  Disease, Phenotype
# 707946  DOID:DOID:2846|MESH:D002012|MONDO:0002443|UMLS...  Disease, Phenotype
#
# [2276 rows x 5 columns]

# %% [markdown]
# ### Disease and Phenotype...

# %% [markdown]
# Too many to do any kind of a blanket merge...  We will:
# 1. Convert those with an HPO id but no DOID to a Phenotype
# 2. Covert those with no HPO id but with a DOID to a Disease
# 3. See how many have both...

# %% [markdown]
# #### Conflicts with no Disease Xref

# %%
pheno_dis = duped_ids.query('duped_types == @this_dup').copy()

qr = pheno_dis.query('label == "Disease"')
no_d_xref = qr[qr['xrefs'].isnull()]['id'].tolist()

duped_ids.query('id in @no_d_xref')
# Out:
#                id                                         name      label  \
# 693924  Q18054140                                     collapse    Disease
# 771011  Q18054140                                     collapse  Phenotype
# 697414    Q188611                                    hypomania    Disease
# 771138    Q188611                                    hypomania  Phenotype
# 701936    Q322370                                   ablepharon    Disease
# 771656    Q322370                                   ablepharon  Phenotype
# 771676   Q3317827  disability affecting intellectual abilities  Phenotype
# 702026   Q3317827  disability affecting intellectual abilities    Disease
# 702239    Q357522                                      Adipsia    Disease
# 771706    Q357522                                      Adipsia  Phenotype
#
#                 xrefs         duped_types
# 693924            NaN  Disease, Phenotype
# 771011            NaN  Disease, Phenotype
# 697414            NaN  Disease, Phenotype
# 771138            NaN  Disease, Phenotype
# 701936            NaN  Disease, Phenotype
# 771656  HP:HP:0011224  Disease, Phenotype
# 771676  HP:HP:0001249  Disease, Phenotype
# 702026            NaN  Disease, Phenotype
# 702239            NaN  Disease, Phenotype
# 771706            NaN  Disease, Phenotype

# %%
this_drop = duped_ids.query('id in @no_d_xref').index.tolist()
drop_idx += this_drop

pheno_dis = pheno_dis.drop(this_drop)

# %%
new_nodes.append(combine_xrefs_and_set_label(duped_ids.loc[this_drop], 'Phenotype'))

# %% [markdown]
# Mostly bad have no xrefs, 2 with phenotypes. I think we can safely merge these to phenotypes

# %% [markdown]
# #### Conflicts with no Pheno Xref

# %%
qr = pheno_dis.query('label == "Phenotype"')
no_p_xref = qr[qr['xrefs'].isnull()]['id'].tolist()

duped_ids.query('id in @no_p_xref')
# Out:
#               id                name      label  \
# 699903  Q2466723  gummatous syphilis    Disease
# 771461  Q2466723  gummatous syphilis  Phenotype
# 771803   Q420915     acroparesthesia  Phenotype
# 702650   Q420915     acroparesthesia    Disease
#
#                                   xrefs         duped_types
# 699903  DOID:DOID:0050584|MONDO:0000363  Disease, Phenotype
# 771461                              NaN  Disease, Phenotype
# 771803                              NaN  Disease, Phenotype
# 702650     DOID:DOID:6690|UMLS:C1332141  Disease, Phenotype

# %% [markdown]
# gummatous syphilis is a Disease, but the acroparesthesia appears to be a Phenotype

# %%
this_drop = duped_ids.query('id in @no_p_xref').index.tolist()
drop_idx += this_drop

new_nodes.append(duped_ids.loc[this_drop].query('name == "gummatous syphilis" and label == "Disease"'))
new_nodes.append(duped_ids.loc[this_drop].query('name == "acroparesthesia" and label == "Phenotype"'))

pheno_dis = pheno_dis.drop(this_drop)

# %% [markdown]
# #### Now for conflicts with no HPO xref

# %%
qr = pheno_dis.query('label == "Phenotype"').dropna(subset=['xrefs'])
no_hpo_xref = qr[~qr['xrefs'].str.contains('HP:')]['id'].tolist()
duped_ids.query('id in @no_hpo_xref')
# Out:
#                id                name      label  \
# 770733   Q1338684    tension headache  Phenotype
# 692928   Q1338684    tension headache    Disease
# 693476   Q1644260    hearing disorder    Disease
# 770923   Q1644260    hearing disorder  Phenotype
# 771160  Q19000619  urination disorder  Phenotype
# 698540  Q19000619  urination disorder    Disease
# 699467  Q21110016      corneal damage    Disease
# 771252  Q21110016      corneal damage  Phenotype
# 699823   Q2346980     absence seizure    Disease
# 771435   Q2346980     absence seizure  Phenotype
# 699838   Q2365426  Acneiform eruption    Disease
# 771438   Q2365426  Acneiform eruption  Phenotype
# 771895    Q498916             apraxia  Phenotype
# 703161    Q498916             apraxia    Disease
# 772198    Q615363         torticollis  Phenotype
# 706230    Q615363         torticollis    Disease
# 706780     Q68833       bone fracture    Disease
# 772253     Q68833       bone fracture  Phenotype
#
#                                                     xrefs         duped_types
# 770733                                       MESH:D018781  Disease, Phenotype
# 692928                                       MESH:D018781  Disease, Phenotype
# 693476  DOID:DOID:12226|MESH:D006311|MONDO:0021945|UML...  Disease, Phenotype
# 770923                                       MESH:D006311  Disease, Phenotype
# 771160                                       MESH:D014555  Disease, Phenotype
# 698540                         DOID:DOID:578|MESH:D014555  Disease, Phenotype
# 699467                                       MESH:D065306  Disease, Phenotype
# 771252                                       MESH:D065306  Disease, Phenotype
# 699823                     DOID:DOID:0070309|MESH:D004832  Disease, Phenotype
# 771435                                       MESH:D004832  Disease, Phenotype
# 699838  DOID:DOID:4399|MESH:D017486|MONDO:0006521|UMLS...  Disease, Phenotype
# 771438                                       MESH:D017486  Disease, Phenotype
# 771895                       MESH:D001072|SNOMED:68345001  Disease, Phenotype
# 703161     DOID:DOID:0060135|MESH:D001072|SNOMED:68345001  Disease, Phenotype
# 772198                                       MESH:D014103  Disease, Phenotype
# 706230                         MESH:D014103|UMLS:C0040485  Disease, Phenotype
# 706780           MESH:D050723|MONDO:0005315|UMLS:C0016658  Disease, Phenotype
# 772253                                       MESH:D050723  Disease, Phenotype

# %% [markdown]
# `corneal damage` is a phenotype, remainder can be classified as a disease.

# %%
this_drop = duped_ids.query('id in @no_hpo_xref').index.tolist()
drop_idx += this_drop

new_nodes.append(duped_ids.loc[this_drop].query('name == "corneal damage" and label == "Phenotype"'))
new_nodes.append(combine_xrefs_and_set_label(duped_ids.loc[this_drop].query('name != "corneal damage"'), 'Disease'))

pheno_dis = pheno_dis.drop(this_drop)

# %% [markdown]
# #### Conflicts with no DO xref

# %%
qr = pheno_dis.query('label == "Disease"').dropna(subset=['xrefs'])
no_doid_xref = qr[~qr['xrefs'].str.contains('DOID:')]['id'].tolist()
duped_ids.query('id in @no_doid_xref')
# Out:
#               id           name      label  \
# 770493   Q101971           wart  Phenotype
# 691569   Q101971           wart    Disease
# 692297  Q1036696    hypothermia    Disease
# 770507  Q1036696    hypothermia  Phenotype
# 770519   Q105688        hypoxia  Phenotype
# ...          ...            ...        ...
# 707895   Q970208  liver failure    Disease
# 772496   Q974792    albuminuria  Phenotype
# 707914   Q974792    albuminuria    Disease
# 772497   Q974869   leukocytosis  Phenotype
# 707915   Q974869   leukocytosis    Disease
#
#                                              xrefs         duped_types
# 770493                  HP:HP:0200043|MESH:D014860  Disease, Phenotype
# 691569                  MESH:D014860|UMLS:C3665596  Disease, Phenotype
# 692297                  MESH:D007035|UMLS:C0020672  Disease, Phenotype
# 770507                  HP:HP:0002045|MESH:D007035  Disease, Phenotype
# 770519                  HP:HP:0012418|MESH:D000860  Disease, Phenotype
# ...                                            ...                 ...
# 707895  MESH:D017093|SNOMED:59927004|UMLS:C0085605  Disease, Phenotype
# 772496                  HP:HP:0012592|MESH:D000419  Disease, Phenotype
# 707914                  MESH:D000419|UMLS:C0001925  Disease, Phenotype
# 772497                  HP:HP:0001974|MESH:D007964  Disease, Phenotype
# 707915                  MESH:D007964|UMLS:C0023518  Disease, Phenotype
#
# [352 rows x 5 columns]

# %% [markdown]
# Lots of examples here... This small smattering looks like Primarily phenotypes...
#
# Lets take a bigger sample to make sure

# %%
duped_ids.query('id in @no_doid_xref').drop_duplicates(subset=['id']).sample(40)
# Out:
#                id                                        name      label  \
# 704111  Q54974362                     end-stage liver disease    Disease
# 770993   Q1759560                                    microtia  Phenotype
# 771738   Q3740609                  seasonal allergic rhinitis  Phenotype
# 707518    Q816422                                dysmenorrhea    Disease
# 770773   Q1424491                     Aplasia cutis congenita  Phenotype
# 771850   Q4677943               acute myelomonocytic leukemia  Phenotype
# 692652    Q117060                                  spasticity    Disease
# 771648    Q318005                          nocturnal enuresis  Phenotype
# 772012   Q5572455                           Glutaric aciduria  Phenotype
# 772496    Q974792                                 albuminuria  Phenotype
# 702199   Q3513620              junctional ectopic tachycardia    Disease
# 772448    Q923164                          expressive aphasia  Phenotype
# 704495  Q55083510                         spastic paraparesis    Disease
# 770493    Q101971                                        wart  Phenotype
# 772113     Q56002                     ventricular tachycardia  Phenotype
# 770633   Q1147182                          fecal incontinence  Phenotype
# 772476    Q955454                                  Coxa valga  Phenotype
# 771473  Q25324230                             pancreatic cyst  Phenotype
# 771913    Q511818                                      tetany  Phenotype
# 692900   Q1324592                                laryngospasm    Disease
# 772391    Q824292                                hyponatremia  Phenotype
# 770872   Q1581308                     conductive hearing loss  Phenotype
# 693130   Q1457267                              schizencephaly    Disease
# 704492  Q55083281                           multiple fracture    Disease
# 771445   Q2406697                                Tetra-amelia  Phenotype
# 770976   Q1734755                             carcinoid tumor  Phenotype
# 772014  Q55762930                metaphyseal chondrodysplasia  Phenotype
# 770573  Q10748814                              megalencephaly  Phenotype
# 692994   Q1363741                                erythroderma    Disease
# 770767    Q141440                               brain abscess  Phenotype
# 772413    Q848662                    ventricular fibrillation  Phenotype
# 770524   Q1061988                                 Flail chest  Phenotype
# 692458   Q1079120                              hyperlipidemia    Disease
# 770827   Q1510899                              hemoperitoneum  Phenotype
# 699912   Q2477062                           cardiogenic shock    Disease
# 702484   Q3922672                                   progenism    Disease
# 771468   Q2520684                                    odontoma  Phenotype
# 699895    Q246040  congenital cystic adenomatoid malformation    Disease
# 692555   Q1135124             agenesis of the corpus callosum    Disease
# 771641   Q3144218                        juvenile macromastia  Phenotype
#
#                                                     xrefs         duped_types
# 704111                         MESH:D058625|UMLS:C2936476  Disease, Phenotype
# 770993             HP:HP:0008551|MESH:D065817|OMIM:600674  Disease, Phenotype
# 771738                         HP:HP:0012395|MESH:D006255  Disease, Phenotype
# 707518                         MESH:D004412|UMLS:C0013390  Disease, Phenotype
# 770773                          HP:HP:0001057|OMIM:107600  Disease, Phenotype
# 771850                         HP:HP:0004820|MESH:D015479  Disease, Phenotype
# 692652                         MESH:D009128|UMLS:C0026838  Disease, Phenotype
# 771648                         HP:HP:0010677|MESH:D053206  Disease, Phenotype
# 772012                                      HP:HP:0003150  Disease, Phenotype
# 772496                         HP:HP:0012592|MESH:D000419  Disease, Phenotype
# 702199  MESH:D013613|MONDO:0017989|ORPHA:3283|UMLS:C00...  Disease, Phenotype
# 772448                         HP:HP:0002427|MESH:D001039  Disease, Phenotype
# 704495                         MESH:D020336|UMLS:C0037771  Disease, Phenotype
# 770493                         HP:HP:0200043|MESH:D014860  Disease, Phenotype
# 772113                         HP:HP:0004756|MESH:D017180  Disease, Phenotype
# 770633                         HP:HP:0002607|MESH:D005242  Disease, Phenotype
# 772476                         HP:HP:0002673|MESH:D060906  Disease, Phenotype
# 771473                         HP:HP:0001737|MESH:D010181  Disease, Phenotype
# 771913                         HP:HP:0001281|MESH:D013746  Disease, Phenotype
# 692900                         MESH:D007826|UMLS:C0023066  Disease, Phenotype
# 772391                         HP:HP:0002902|MESH:D007010  Disease, Phenotype
# 770872                         HP:HP:0000405|MESH:D006314  Disease, Phenotype
# 693130  MESH:D065707|MONDO:0010011|OMIM:269160|ORPHA:7...  Disease, Phenotype
# 704492  MESH:D000069076|UMLS:C0016655|UMLS:C1833752|UM...  Disease, Phenotype
# 771445             HP:HP:0003057|MESH:C536498|OMIM:273395  Disease, Phenotype
# 770976             HP:HP:0100570|MESH:D002276|OMIM:114900  Disease, Phenotype
# 772014                                      HP:HP:0005871  Disease, Phenotype
# 770573             HP:HP:0001355|MESH:D058627|OMIM:155350  Disease, Phenotype
# 692994         MESH:D003873|SNOMED:55012006|UMLS:C0011606  Disease, Phenotype
# 770767                         HP:HP:0030049|MESH:D001922  Disease, Phenotype
# 772413                         HP:HP:0001663|MESH:D014693  Disease, Phenotype
# 770524         HP:HP:0030207|MESH:D005409|SNOMED:78011002  Disease, Phenotype
# 692458  MESH:D006949|MONDO:0015901|MONDO:0021187|ORPHA...  Disease, Phenotype
# 770827                         HP:HP:0011854|MESH:D006465  Disease, Phenotype
# 699912             MESH:D012770|ORPHA:97292|UMLS:C0036980  Disease, Phenotype
# 702484  MESH:D008313|MONDO:0008312|OMIM:176700|ORPHA:2...  Disease, Phenotype
# 771468                         HP:HP:0011068|MESH:D009810  Disease, Phenotype
# 699895  MESH:D015615|MONDO:0016580|ORPHA:2444|SNOMED:1...  Disease, Phenotype
# 692555  MESH:D061085|MONDO:0009022|OMIM:217990|ORPHA:2...  Disease, Phenotype
# 771641             HP:HP:0010313|MESH:C536821|OMIM:113670  Disease, Phenotype

# %% [markdown]
# Lots of HPO Xrefs on these, most look like phenotypes, so we will coerce them all to phenotypes, while maintaining the original Xref

# %%
this_drop = duped_ids.query('id in @no_doid_xref').index.tolist()
drop_idx += this_drop

new_nodes.append(combine_xrefs_and_set_label(duped_ids.loc[this_drop], 'Phenotype'))

pheno_dis = pheno_dis.drop(this_drop)

# %% [markdown]
# What's left should have both DO and HPO xref identifiers

# %%
pheno_dis
# Out:
#                 id                               name      label  \
# 691564    Q1016605                   Burkitt lymphoma    Disease
# 770492    Q1016605                   Burkitt lymphoma  Phenotype
# 770496  Q102293266    calcium oxalate nephrolithiasis  Phenotype
# 691601  Q102293266    calcium oxalate nephrolithiasis    Disease
# 770497  Q102296856  glutathione synthetase deficiency  Phenotype
# ...            ...                                ...        ...
# 772503     Q979168                     cerebral edema  Phenotype
# 772505     Q994859                     homocystinuria  Phenotype
# 707945     Q994859                     homocystinuria    Disease
# 772506     Q994942                            bruxism  Phenotype
# 707946     Q994942                            bruxism    Disease
#
#                                                     xrefs         duped_types
# 691564  DOID:DOID:8584|MESH:D002051|OMIM:113970|ORPHA:...  Disease, Phenotype
# 770492             HP:HP:0030080|MESH:D002051|OMIM:113970  Disease, Phenotype
# 770496                                      HP:HP:0008672  Disease, Phenotype
# 691601                                  DOID:DOID:0080652  Disease, Phenotype
# 770497  HP:HP:0003343|MESH:C536835|OMIM:266130|SNOMED:...  Disease, Phenotype
# ...                                                   ...                 ...
# 772503                         HP:HP:0002181|MESH:D001929  Disease, Phenotype
# 772505  HP:HP:0002156|MESH:D006712|OMIM:236200|OMIM:23...  Disease, Phenotype
# 707945  DOID:DOID:9263|MESH:D006712|MONDO:0004737|OMIM...  Disease, Phenotype
# 772506                         HP:HP:0003763|MESH:D002012  Disease, Phenotype
# 707946  DOID:DOID:2846|MESH:D002012|MONDO:0002443|UMLS...  Disease, Phenotype
#
# [1892 rows x 5 columns]

# %% [markdown]
# Still 900 confilcts... all we can do here is split the concepts.
#
# We'll keep the cannonical wikidata item as a Disease, and make new phenotypes with the HPO Xrefs...

# %%
pheno_nodes = get_curi_xrefs(pheno_dis.query('label == "Phenotype"'), 'HP')
pheno_nodes = pheno_nodes.merge(pheno_dis.query('label == "Phenotype"'), how='left', on='id', suffixes=('', '_old'))
xrefs = pheno_nodes['xrefs_old']

# Remove the hpo xref from the nodes
xrefs = split_col(xrefs, '|').apply(lambda x: [r for r in x if not r.startswith('HP:')]).apply(lambda x: '|'.join(x))

add_nodes = xrefs_to_new_nodes(pheno_nodes)
add_nodes['xrefs'] = xrefs

# Add the Pheno and disease nodes
new_nodes.append(add_nodes.replace('', float('nan')))
new_nodes.append(pheno_dis.query('label == "Disease"'))

# Add the Disease to pheno edges
new_edges.append(xrefs_to_new_edges(pheno_nodes, 'id', 'xrefs', 'presents'))

# %%
drop_idx += pheno_dis.index.tolist()

# %% [markdown]
# ## Putting it all back together

# %%
nodes = nodes.drop(drop_idx)
nodes = pd.concat([nodes]+new_nodes, sort=False, ignore_index=True).drop('duped_types', axis=1)

nodes
# Out:
#                id                    name    label  \
# 0        Q1010102            Bunyaviridae    Taxon
# 1        Q1026758           Caliciviridae    Taxon
# 2       Q10457821  Conidiobolus coronatus    Taxon
# 3       Q10462705  Cryptostroma corticale    Taxon
# 4       Q10584816   Microsporum distortum    Taxon
# ...           ...                     ...      ...
# 808739    Q976388          acute leukemia  Disease
# 808740    Q977787      gallbladder cancer  Disease
# 808741    Q979168          cerebral edema  Disease
# 808742    Q994859          homocystinuria  Disease
# 808743    Q994942                 bruxism  Disease
#
#                                                     xrefs
# 0                                                     NaN
# 1                                         NCBITaxon:11974
# 2                                         NCBITaxon:34488
# 3                                       NCBITaxon:1463975
# 4                                        NCBITaxon:101202
# ...                                                   ...
# 808739  DOID:DOID:12603|MESH:C564112|MONDO:0010643|OMI...
# 808740  DOID:DOID:3121|MONDO:0005411|UMLS:C0016978|UML...
# 808741  DOID:DOID:4724|MESH:D001929|MONDO:0006684|UMLS...
# 808742  DOID:DOID:9263|MESH:D006712|MONDO:0004737|OMIM...
# 808743  DOID:DOID:2846|MESH:D002012|MONDO:0002443|UMLS...
#
# [808744 rows x 4 columns]

# %%
edges = pd.concat([edges]+new_edges, sort=False, ignore_index=True)

# %%
edges
# Out:
#          start_id         end_id      type      dsrc_type comp_type
# 0         Q570260      Q19000458    causes  crowd_sourced       NaN
# 1        Q7435269      Q55009424    causes  crowd_sourced       NaN
# 2        Q2368907      Q19001357    causes  crowd_sourced       NaN
# 3        Q1648694      Q19000740    causes  crowd_sourced       NaN
# 4        Q1437858      Q55009396    causes  crowd_sourced       NaN
# ...           ...            ...       ...            ...       ...
# 4025294   Q976388  HP:HP:0002488  presents       computed     split
# 4025295   Q977787  HP:HP:0100575  presents       computed     split
# 4025296   Q979168  HP:HP:0002181  presents       computed     split
# 4025297   Q994859  HP:HP:0002156  presents       computed     split
# 4025298   Q994942  HP:HP:0003763  presents       computed     split
#
# [4025299 rows x 5 columns]

# %% [markdown]
# ## Cleaning Up Edges
#
# Some of the Edge Queryies we were less specific about how we defined node types... So we may have some IDs that don't appear in any of the nodes. We need to remove these.

# %%
print('{:,}'.format(len(edges)))

node_ids = nodes['id'].unique()
edges = edges.query('start_id in @node_ids and end_id in @node_ids')

print('{:,}'.format(len(edges)))
# Out:
# 4,025,299
# 1,658,114

# %%
edges = edges.drop_duplicates(subset=['start_id', 'end_id', 'type'])
print('{:,}'.format(len(edges)))
# Out:
# 1,436,746

# %%
count_plot_h(edges['dsrc_type'])
# Out:
# <AxesSubplot:xlabel='dsrc_type'>

# %%
count_plot_h(edges['comp_type'])
# Out:
# <AxesSubplot:xlabel='comp_type'>

# %%
count_plot_h(edges['type'])
# Out:
# <AxesSubplot:xlabel='type'>

# %%
count_plot_h(nodes['label'])
# Out:
# <AxesSubplot:xlabel='label'>

# %%
combo = combine_nodes_and_edges(nodes, edges)

# %%
meta_edges = combo['start_label'] + '_' + combo['type'] + '_' + combo['end_label']
meta_edges.nunique()
# Out:
# 46

# %%
count_plot_h(meta_edges.value_counts().head(10))
# Out:
# <AxesSubplot:>

# %%
count_plot_h(meta_edges.value_counts().head(20).tail(10))
# Out:
# <AxesSubplot:>

# %%
count_plot_h(meta_edges.value_counts().head(30).tail(10))
# Out:
# <AxesSubplot:>

# %%
count_plot_h(meta_edges.value_counts().head(40).tail(10))
# Out:
# <AxesSubplot:>

# %%
count_plot_h(meta_edges.value_counts().tail(6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Many of the low count metaedges are either mistakes, or otherwise useless noisy edges:
#
# Compound to protein edges are ok as they will later be changed to simplied semmantics:
#
# One other should be examined:
#
# - Disease Presents Diseases
#
# This edge is of diseases that are also likely phenotypes, so we should have the proper phenotype in place instead of the disease
#
# For now we will drop these edges...

# %%
drop_me = ['Protein_enables_Biological Process', 'Phenotype_subclass_of_Phenotype', 'Phenotype_subclass_of_Disease',
          'Disease_subclass_of_Phenotype', 'Phenotype_presents_Disease', 'Protein_involved_in_Molecular Function',
          'Cellular Component_subclass_of_Cellular Component', 'Phenotype_presents_Phenotype', 
          'Protein_agonist_Protein', 'Protein_involved_in_Cellular Component', 'Protein_involved_in_Disease',
          'Gene_associated_with_Gene', 'Gene_subclass_of_Gene', 'Disease_causes_Disease']

# %%
new_drop_index = meta_edges.rename('me').to_frame().query('me in @drop_me').index
len(new_drop_index)
# Out:
# 1008

# %% [markdown]
# ### Now examine the Likely Disease Phenotype Edges...

# %%
dis_pheno_idx = combo.query('start_label == "Disease" and end_label == "Disease" and type != "subclass_of"').index

# %%
combo.loc[dis_pheno_idx].head(20)
# Out:
#           start_id    end_id      type      dsrc_type comp_type  \
# 308        Q184627  Q1223924    causes  crowd_sourced       NaN
# 3969647   Q4463309   Q505142  presents  crowd_sourced       NaN
# 3969660   Q1790424    Q12192  presents  crowd_sourced       NaN
# 3969665    Q837054   Q114085  presents  crowd_sourced       NaN
# 3969666   Q2271749    Q82504  presents  crowd_sourced       NaN
# 3969667   Q4710773    Q82504  presents  crowd_sourced       NaN
# 3969668  Q10529545    Q79928  presents  crowd_sourced       NaN
# 3969730    Q495146   Q505142  presents  crowd_sourced       NaN
# 3969736   Q1048084   Q505142  presents  crowd_sourced       NaN
# 3969740   Q2264130   Q505142  presents  crowd_sourced       NaN
# 3969741   Q2528129   Q505142  presents  crowd_sourced       NaN
# 3969744   Q3091959   Q505142  presents  crowd_sourced       NaN
# 3969748  Q11542703   Q505142  presents  crowd_sourced       NaN
# 3969788    Q378681  Q1097957  presents  crowd_sourced       NaN
# 3969852   Q2076966  Q1459821  presents  crowd_sourced       NaN
# 3969867    Q201989  Q1364270  presents  crowd_sourced       NaN
# 3969869    Q210427  Q1282114  presents  crowd_sourced       NaN
# 3969882    Q963944  Q1877550  presents  crowd_sourced       NaN
# 3969885   Q1048084  Q2028354  presents  crowd_sourced       NaN
# 3969901   Q1856914  Q1877550  presents  crowd_sourced       NaN
#
#                                      start_name                     end_name  \
# 308              human papillomavirus infection               papillomatosis
# 3969647                   trichostrongyloidosis                 eosinophilia
# 3969660       idiopathic interstitial pneumonia                    pneumonia
# 3969665  obsolete adenovirus infectious disease                     rhinitis
# 3969666         subacute bacterial endocarditis                 endocarditis
# 3969667                   Loeffler endocarditis                 endocarditis
# 3969668                        hyperandrogenism                         acne
# 3969730                             trichinosis                 eosinophilia
# 3969736                         opisthorchiasis                 eosinophilia
# 3969740                            trichuriasis                 eosinophilia
# 3969741                          paragonimiasis                 eosinophilia
# 3969744                             anisakiasis                 eosinophilia
# 3969748                          metagonimiasis                 eosinophilia
# 3969788               peripheral artery disease    intermittent claudication
# 3969852                 cytomegaloviral disease            holoprosencephaly
# 3969867                            Lyme disease  hypertrophic cardiomyopathy
# 3969869                          cerebral palsy              speech disorder
# 3969882                             melioidosis                 lung abscess
# 3969885                         opisthorchiasis           biliary dyskinesia
# 3969901                             nocardiosis                 lung abscess
#
#         start_label end_label
# 308         Disease   Disease
# 3969647     Disease   Disease
# 3969660     Disease   Disease
# 3969665     Disease   Disease
# 3969666     Disease   Disease
# 3969667     Disease   Disease
# 3969668     Disease   Disease
# 3969730     Disease   Disease
# 3969736     Disease   Disease
# 3969740     Disease   Disease
# 3969741     Disease   Disease
# 3969744     Disease   Disease
# 3969748     Disease   Disease
# 3969788     Disease   Disease
# 3969852     Disease   Disease
# 3969867     Disease   Disease
# 3969869     Disease   Disease
# 3969882     Disease   Disease
# 3969885     Disease   Disease
# 3969901     Disease   Disease

# %%
likely_phenos = combo.loc[dis_pheno_idx]['end_id']

# %%
pheno_names = nodes.query('id in @likely_phenos')['name']
pheno_ids = nodes.query('name in @pheno_names and label == "Phenotype"')['id']
pheno_map = combo.query('start_label == "Disease" and end_id in @pheno_ids').set_index('start_id')['end_id'].to_dict()

# %%
edges.loc[dis_pheno_idx, 'end_id'] = edges.loc[dis_pheno_idx]['end_id'].map(pheno_map)

# %%
edges.loc[dis_pheno_idx]
# Out:
#          start_id         end_id      type      dsrc_type comp_type
# 308       Q184627            NaN    causes  crowd_sourced       NaN
# 3969647  Q4463309  HP:HP:0001880  presents  crowd_sourced       NaN
# 3969660  Q1790424  HP:HP:0002090  presents  crowd_sourced       NaN
# 3969665   Q837054  HP:HP:0012384  presents  crowd_sourced       NaN
# 3969666  Q2271749  HP:HP:0100584  presents  crowd_sourced       NaN
# ...           ...            ...       ...            ...       ...
# 3972001  Q1282114  HP:HP:0100021  presents  crowd_sourced       NaN
# 3972002  Q1956682  HP:HP:0002047  presents  crowd_sourced       NaN
# 3972003  Q2844600  HP:HP:0006785  presents  crowd_sourced       NaN
# 3972004  Q4118092  HP:HP:0005508  presents  crowd_sourced       NaN
# 3972005    Q10874  HP:HP:0007716  presents  crowd_sourced       NaN
#
# [612 rows x 5 columns]

# %%
edges = edges.drop(new_drop_index)
edges = edges.dropna(subset=['end_id'])

# %%
combo = combine_nodes_and_edges(nodes, edges)

# %%
meta_edges = combo['start_label'] + '_' + combo['type'] + '_' + combo['end_label']
meta_edges.nunique()
# Out:
# 32

# %%
plt.figure(figsize=(8,12))
count_plot_h(meta_edges)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Save out Resultant Edges

# %%
out_dir = Path('../results/')

out_dir.mkdir(parents=True, exist_ok=True)

nodes.to_csv(out_dir.joinpath('01c_nodes.csv'), index=False)
edges.to_csv(out_dir.joinpath('01c_edges.csv'), index=False)
