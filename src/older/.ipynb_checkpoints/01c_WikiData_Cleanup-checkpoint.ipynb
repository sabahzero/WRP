# %% [markdown]
# # Cleaning up WikiData Query Results
#
# There are several issues with WikiData queries, one of the biggest is that some queries for different Node types will yield some of the same nodes.  These need to be reconciled before continuing (1 node type for one ID).
#
# ***Warning*** The cleanup pipeline is a result of my queries to WikiData at the time that I performed them.  As WikiData is constantaly changing, on future runs, changes may need to be peformed to get this notebook to complete successfully. I've outlined all decisions made to resolve conflicts in a way that hopefully allows future conflicts to be similarly resolved

# %%
# Make issue for script

import pandas as pd
from pathlib import Path
from data_tools import combine_nodes_and_edges
from data_tools.df_processing import combine_group_cols_on_char, split_col
from data_tools.wiki import xref_to_wd_item, get_curi_xrefs
from data_tools.plotting import count_plot_h

# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# New line recommended by notebook
from tqdm.autonotebook import tqdm
# Out:
# /Users/sulhasan/opt/anaconda3/lib/python3.8/site-packages/data_tools/df_processing.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
prev_dir = Path('../results/').resolve()
nodes = pd.read_csv(prev_dir.joinpath('nodes.csv'), dtype=str)
edges = pd.read_csv(prev_dir.joinpath('edges.csv'), dtype=str)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-bba9c8b494d5> in <module>
#       1 prev_dir = Path('../results/').resolve()
# ----> 2 nodes = pd.read_csv(prev_dir.joinpath('nodes.csv'), dtype=str)
#       3 edges = pd.read_csv(prev_dir.joinpath('edges.csv'), dtype=str)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/sulhasan/Desktop/Project/WRP/results/nodes.csv'

# %% [markdown]
# # Reconcile Nodes

# %%
drop_idx = []
new_nodes = []
new_edges = []

# %%
# adjust?

duped_ids = nodes[nodes['id'].duplicated(keep=False)].sort_values('id')
duped_ids['id'].nunique()
# Out:
# 1158

# %%
dup_type_map = duped_ids.groupby('id')['label'].apply(lambda x: ', '.join(sorted(list(x)))).to_dict()
duped_ids['duped_types'] = duped_ids['id'].map(dup_type_map)

# %%
dup_frac = duped_ids['duped_types'].value_counts() / duped_ids['duped_types'].value_counts().max()

# %%
count_plot_h(duped_ids['duped_types'].value_counts() // 2)

# 1,180 nodes showing up in both disease and phenotype node type
## Why not have the nodes show up among all, why compare between two?

# %%
# need all this to ensure consistent ordering each time notebook is run...
dt = (duped_ids['duped_types'].value_counts()
                              .to_frame()
                              .reset_index()
                              .sort_values(['duped_types', 'index'], ascending=(True, True))['index']
                              .tolist())

# %%
# Keep a consistent order for future iterations...

dt = ['Anatomy, Disease', 
      'Cellular Component, Phenotype', 
      'Disease, Gene', 
      'Disease, Taxon',
      'Anatomy, Phenotype',
      'Compound, Gene',
      'Biological Process, Phenotype',
      'Anatomy, Cellular Component',
      'Biological Process, Disease',
      'Compound, Protein',
      'Biological Process, Molecular Function',
      'Biological Process, Pathway',
      'Disease, Phenotype']

# Check that all show 
print(dt[0:13])
# Out:
# ['Anatomy, Disease', 'Cellular Component, Phenotype', 'Disease, Gene', 'Disease, Taxon', 'Anatomy, Phenotype', 'Compound, Gene', 'Biological Process, Phenotype', 'Anatomy, Cellular Component', 'Biological Process, Disease', 'Compound, Protein', 'Biological Process, Molecular Function', 'Biological Process, Pathway', 'Disease, Phenotype']

# %%
dti = iter(dt)

# %%
# Add more documentation later

this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')

# No show for these, why? 
## Working after increasing limit on compounds -- maybe there weren't connections?
### More compounds mean more likely to show up as duplicate
### How to classify if something is a disease vs phenotype, and how to compute
#### If everything is assigned as Disease (Disease, Phenotype) ==> if we flip, do we get same downstream result in algorithm?
##### If different, then look into (biologically, contextually) metric for what's better?
# Out:
#               id                           name    label           xrefs  \
# 736771  Q7170418  persistent pupillary membrane  Anatomy  UBERON:0002269
# 451190  Q7170418  persistent pupillary membrane  Disease   UMLS:C0344541
#
#              duped_types
# 736771  Anatomy, Disease
# 451190  Anatomy, Disease

# %% [markdown]
# This is a Disease, but it is located in anatomy...

# %%
xid = duped_ids.query('duped_types == @this_dup and label == "Anatomy"')['xrefs'].values[0]
qid = xref_to_wd_item(nodes, xid, always_list=True)
nodes.query('id in @qid')
# Out:
#               id                           name    label           xrefs
# 451190  Q7170418  persistent pupillary membrane  Disease   UMLS:C0344541
# 736771  Q7170418  persistent pupillary membrane  Anatomy  UBERON:0002269

# %% [markdown]
# No other WD items have that UBERON identifier. Drop the Anatomy, but add a new edge

# %%
def xrefs_to_new_nodes(combined_nodes, new_names=None):
    add_nodes = combined_nodes[['xrefs', 'name', 'label']].rename(columns={'xrefs': 'id'}).copy()
    if new_names is not None:
        add_nodes['name'] = new_names
    return add_nodes
    
def xrefs_to_new_edges(combined_nodes, start_col, end_col, semmantics):
    # ensure we've got a dataframe (single index will return series)
    if type(combined_nodes) == pd.Series:
        combined_nodes = combined_nodes.to_frame().T
    
    add_edges = combined_nodes[['xrefs', 'id']].rename(columns={start_col: 'start_id', end_col: 'end_id'}).copy()
    add_edges['type'] = semmantics
    add_edges['dsrc_type'] = 'computed'
    add_edges['comp_type'] = 'split'
    return add_edges.loc[:, ['start_id','end_id','type','dsrc_type','comp_type']]

# %%
def combine_xrefs_and_set_label(combined_nodes, label):
    add_nodes = combine_group_cols_on_char(combined_nodes, ['id'], ['xrefs'], prog=False)
    add_nodes['label'] = label
    add_nodes = add_nodes.drop('duped_types', axis=1)
    return add_nodes

# %%
# Prepare to drop the bad edge
to_drop = [duped_ids.query('duped_types == @this_dup and label == "Anatomy"').index.values[0]]
drop_idx += to_drop

# Add the new node
add_node = xrefs_to_new_nodes(duped_ids.loc[to_drop], 'Pupillary membrane')
new_nodes.append(add_node)

# And add the edge
add_edge = xrefs_to_new_edges(duped_ids.loc[to_drop], 'id', 'xrefs', 'localized_to')
new_edges.append(add_edge)

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#              id                    name               label  \
# 734592  Q767442  neurofibrillary tangle  Cellular Component
# 602688  Q767442  neurofibrillary tangle           Phenotype
#
#                           xrefs                    duped_types
# 734592               GO:0097418  Cellular Component, Phenotype
# 602688  HP:0002185|MESH:D016874  Cellular Component, Phenotype

# %% [markdown]
# While a valid phenotype, seems ot have more incommon with the cell component...

# %%
this_drop = duped_ids.query('duped_types == @this_dup').index.tolist()
drop_idx += this_drop
new_nodes.append(combine_xrefs_and_set_label(duped_ids.loc[this_drop], 'Cellular Component'))

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#                id name    label  \
# 603752  Q14913011  MVK     Gene
# 437351  Q14913011  MVK  Disease
#
#                                                     xrefs    duped_types
# 603752  ENSG:ENSG00000110921|HGNC:7530|NCBIGene:4598|O...  Disease, Gene
# 437351  MONDO:MONDO:0012481|OMIM:175900|OMIM:251170|OM...  Disease, Gene

# %% [markdown]
# This is a Gene... look for this MONDO ID elsewhere...

# %%
xid = duped_ids.query('duped_types == @this_dup and label == "Disease"')['xrefs'].values[0]
xid = [x for x in xid.split('|') if x.startswith('MONDO:')][0]
mondo_ids = xref_to_wd_item(nodes, xid, always_list=True)
nodes.query('id in @mondo_ids')
# Out:
#                id                name    label  \
# 437351  Q14913011                 MVK  Disease
# 445388   Q3043158  mevalonic aciduria  Disease
# 603752  Q14913011                 MVK     Gene
#
#                                                     xrefs
# 437351  MONDO:MONDO:0012481|OMIM:175900|OMIM:251170|OM...
# 445388  DOID:DOID:0050452|MESH:D054078|MONDO:MONDO:001...
# 603752  ENSG:ENSG00000110921|HGNC:7530|NCBIGene:4598|O...

# %% [markdown]
# The Disease already exists, prepare to drop and ensure that the edge between the two exists

# %%
to_drop = duped_ids.query('duped_types == @this_dup and label == "Disease"').index.values[0]
drop_idx.append(to_drop)

sid, eid = nodes.query('id in @mondo_ids')['id'].unique()
edges.query('(start_id == @sid and end_id == @eid) or (start_id == @eid and end_id == @sid)')
# Out:
#           start_id    end_id             type      dsrc_type comp_type
# 3785037  Q14913011  Q3043158  associated_with  crowd_sourced       NaN

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#              id                            name    label  \
# 114     Q184627  human papillomavirus infection    Taxon
# 438162  Q184627  human papillomavirus infection  Disease
#
#                                                     xrefs     duped_types
# 114                                                   NaN  Disease, Taxon
# 438162  DOID:DOID:11166|MONDO:MONDO:0005161|SNOMED:240...  Disease, Taxon

# %% [markdown]
# HPV infection is not a taxon, but rather a disease. It has a cause of ... hpv

# %%
drop_idx += duped_ids.query('duped_types == @this_dup and label == "Taxon"').index.tolist()

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#               id                name      label                        xrefs  \
# 600999  Q1174313            Diastema  Phenotype      HP:0000699|MESH:D003970
# 734780  Q1174313            Diastema    Anatomy  MESH:D003970|UBERON:0012111
# 735820   Q356002  anterior pituitary    Anatomy  MESH:D010903|UBERON:0002196
# 602047   Q356002  anterior pituitary  Phenotype      HP:0010625|MESH:D010903
#
#                duped_types
# 600999  Anatomy, Phenotype
# 734780  Anatomy, Phenotype
# 735820  Anatomy, Phenotype
# 602047  Anatomy, Phenotype

# %% [markdown]
# Both well annotated, but seeming more like anatomy nodes... will keep the xrefs

# %%
this_drop = duped_ids.query('duped_types == @this_dup').index.tolist()
drop_idx += this_drop
new_nodes.append(combine_xrefs_and_set_label(duped_ids.loc[this_drop], 'Anatomy'))

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#                id   name     label  \
# 453348  Q14911781  ALDH2  Compound
# 603665  Q14911781  ALDH2      Gene
# 660852    Q418553    NGB      Gene
# 592287    Q418553    NGB  Compound
#
#                                                     xrefs     duped_types
# 453348                                                NaN  Compound, Gene
# 603665  ENSG:ENSG00000111275|HGNC:404|NCBIGene:217|OMI...  Compound, Gene
# 660852  ENSG:ENSG00000165553|HGNC:14077|NCBIGene:58157...  Compound, Gene
# 592287                                                NaN  Compound, Gene

# %% [markdown]
# Two compounds with no xrefs... Just drop the compound version

# %%
drop_idx = drop_idx + duped_ids.query('duped_types == @this_dup and label == "Compound"').index.tolist()

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#                id                     name               label  \
# 703090  Q14864096  skeletal muscle atrophy  Biological Process
# 601161  Q14864096  skeletal muscle atrophy           Phenotype
# 706591  Q15322281      chromosome breakage  Biological Process
# 601191  Q15322281      chromosome breakage           Phenotype
# 602053     Q35831                    sleep           Phenotype
# 729806     Q35831                    sleep  Biological Process
#
#                           xrefs                    duped_types
# 703090               GO:0014732  Biological Process, Phenotype
# 601161               HP:0003202  Biological Process, Phenotype
# 706591               GO:0031052  Biological Process, Phenotype
# 601191  HP:0003220|MESH:D019457  Biological Process, Phenotype
# 602053  HP:0002329|MESH:D012890  Biological Process, Phenotype
# 729806               GO:0030431  Biological Process, Phenotype

# %% [markdown]
# Phenotypes and biological Processes... GO is a really tight annotaiton system, so don't really want to remove... will keep the pheno annotations...

# %%
this_drop = duped_ids.query('duped_types == @this_dup').index.tolist()
drop_idx += this_drop
new_nodes.append(combine_xrefs_and_set_label(duped_ids.loc[this_drop], 'Biological Process'))

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#               id                    name               label  \
# 734427  Q4736445          climbing fiber  Cellular Component
# 736071  Q4736445          climbing fiber             Anatomy
# 734595   Q776995  neuromuscular junction  Cellular Component
# 736952   Q776995  neuromuscular junction             Anatomy
#
#                               xrefs                  duped_types
# 734427                   GO:0044301  Anatomy, Cellular Component
# 736071               UBERON:2002185  Anatomy, Cellular Component
# 734595                   GO:0031594  Anatomy, Cellular Component
# 736952  MESH:D009469|UBERON:0001029  Anatomy, Cellular Component

# %% [markdown]
# These are all Cell Component Terms... `myelin` and `climbing fiber` have proper uberon annotations, but the remainder are either xref'd to a (close but) incorrect term, or xref to obsolete UBERON terms.

# %%
# Get rid of the conflicting nodes
this_drop = duped_ids.query('duped_types == @this_dup and label == "Anatomy"').index.tolist()
drop_idx = drop_idx + this_drop

# Keep the two ok nodes
keep_xrefs = duped_ids.loc[this_drop].query('name in {!r}'.format(['myelin', 'climbing fiber']))
add_nodes = xrefs_to_new_nodes(keep_xrefs)
new_nodes.append(add_nodes)

# Add links between the two concepts
add_edges = xrefs_to_new_edges(keep_xrefs, 'id', 'xrefs', 'localized_to')
new_edges.append(add_edge)

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#               id                                        name  \
# 730285  Q5898315  hypersensitivity reaction type III disease
# 450107  Q5898315  hypersensitivity reaction type III disease
# 450136  Q5958765                            hypersensitivity
# 730287  Q5958765                            hypersensitivity
# 451595  Q7860879                    type IV hypersensitivity
# 730430  Q7860879                    type IV hypersensitivity
#
#                      label                                              xrefs  \
# 730285  Biological Process                                         GO:0001802
# 450107             Disease  DOID:DOID:1557|MESH:D007105|MONDO:MONDO:000700...
# 450136             Disease  DOID:DOID:0060056|MESH:D006967|MONDO:MONDO:000...
# 730287  Biological Process                                         GO:0002524
# 451595             Disease          DOID:DOID:2916|MESH:D006968|UMLS:C0021070
# 730430  Biological Process                                         GO:0001806
#
#                         duped_types
# 730285  Biological Process, Disease
# 450107  Biological Process, Disease
# 450136  Biological Process, Disease
# 730287  Biological Process, Disease
# 451595  Biological Process, Disease
# 730430  Biological Process, Disease

# %% [markdown]
# Definitely instances of both.. need to split into Biological Processes and Diseases

# %%
this_drop = duped_ids.query('duped_types == @this_dup and label == "Biological Process"').index.tolist()
drop_idx = drop_idx + this_drop

new_nodes.append(xrefs_to_new_nodes(duped_ids.loc[this_drop]))
new_edges.append(xrefs_to_new_edges(duped_ids.loc[this_drop], 'xrefs', 'id', 'causes'))

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#              id      name     label  \
# 455939  Q170617  glucagon  Compound
# 662061  Q170617  glucagon   Protein
#
#                                                     xrefs        duped_types
# 455939  CHEBI:5391|CHEMBL:CHEMBL266481|DB:00040|KEGG:C...  Compound, Protein
# 662061                                                NaN  Compound, Protein

# %% [markdown]
# These are all Polypeptides... However, they have numerous chemical annotations...

# %%
this_drop = duped_ids.query('duped_types == @this_dup').index.tolist()
drop_idx += this_drop
new_nodes.append(combine_xrefs_and_set_label(duped_ids.loc[this_drop], 'Protein'))

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#                id                     name               label       xrefs  \
# 690886  Q14820641  protein kinase activity  Molecular Function  GO:0004672
# 702267  Q14820641  protein kinase activity  Biological Process  GO:0004672
#
#                                    duped_types
# 690886  Biological Process, Molecular Function
# 702267  Biological Process, Molecular Function

# %% [markdown]
# These are all obsolete terms. Drop em all.

# %%
drop_idx = drop_idx + duped_ids.query('duped_types == @this_dup').index.tolist()

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#                id                                   name               label  \
# 702513  Q14859896  cellular amino acid metabolic process  Biological Process
# 687701  Q14859896  cellular amino acid metabolic process             Pathway
# 687702  Q14864262              protein metabolic process             Pathway
# 703152  Q14864262              protein metabolic process  Biological Process
# 703735  Q14866112            apoptotic signaling pathway  Biological Process
# 687703  Q14866112            apoptotic signaling pathway             Pathway
# 687707   Q2792936                       lipid metabolism             Pathway
# 729294   Q2792936                       lipid metabolism  Biological Process
# 690620   Q5768379                Hippo signaling pathway             Pathway
# 730269   Q5768379                Hippo signaling pathway  Biological Process
# 690717     Q84230                              secretion             Pathway
# 730446     Q84230                              secretion  Biological Process
#
#              xrefs                  duped_types
# 702513  GO:0006520  Biological Process, Pathway
# 687701         NaN  Biological Process, Pathway
# 687702         NaN  Biological Process, Pathway
# 703152  GO:0019538  Biological Process, Pathway
# 703735  GO:0097190  Biological Process, Pathway
# 687703         NaN  Biological Process, Pathway
# 687707         NaN  Biological Process, Pathway
# 729294  GO:0006629  Biological Process, Pathway
# 690620         NaN  Biological Process, Pathway
# 730269  GO:0035329  Biological Process, Pathway
# 690717         NaN  Biological Process, Pathway
# 730446  GO:0046903  Biological Process, Pathway

# %% [markdown]
# These pathways have no Xrefs, so we will keep them as GO biological Processes.

# %%
qr = duped_ids.query('duped_types == @this_dup')
drop_idx = drop_idx + qr[qr['xrefs'].isnull()].index.tolist()

# %%
this_dup = next(dti)
duped_ids.query('duped_types == @this_dup')
# Out:
#                 id                             name      label  \
# 600847    Q1016605                 Burkitt lymphoma  Phenotype
# 435620    Q1016605                 Burkitt lymphoma    Disease
# 600848     Q101971                             wart  Phenotype
# 435625     Q101971                             wart    Disease
# 600851  Q102293266  calcium oxalate nephrolithiasis  Phenotype
# ...            ...                              ...        ...
# 602845     Q979168                   cerebral edema  Phenotype
# 602847     Q994859                   homocystinuria  Phenotype
# 452132     Q994859                   homocystinuria    Disease
# 602848     Q994942                          bruxism  Phenotype
# 452133     Q994942                          bruxism    Disease
#
#                                                     xrefs         duped_types
# 600847                HP:0030080|MESH:D002051|OMIM:113970  Disease, Phenotype
# 435620  DOID:DOID:8584|MESH:D002051|OMIM:113970|ORPHA:...  Disease, Phenotype
# 600848                            HP:0200043|MESH:D014860  Disease, Phenotype
# 435625                         MESH:D014860|UMLS:C3665596  Disease, Phenotype
# 600851                                         HP:0008672  Disease, Phenotype
# ...                                                   ...                 ...
# 602845                            HP:0002181|MESH:D001929  Disease, Phenotype
# 602847  HP:0002156|MESH:D006712|OMIM:236200|OMIM:23625...  Disease, Phenotype
# 452132  DOID:DOID:9263|MESH:D006712|MONDO:MONDO:000473...  Disease, Phenotype
# 602848                            HP:0003763|MESH:D002012  Disease, Phenotype
# 452133  DOID:DOID:2846|MESH:D002012|MONDO:MONDO:000244...  Disease, Phenotype
#
# [2260 rows x 5 columns]

# %% [markdown]
# ### Disease and Phenotype...

# %% [markdown]
# Too many to do any kind of a blanket merge...  We will:
# 1. Convert those with an HPO id but no DOID to a Phenotype
# 2. Covert those with no HPO id but with a DOID to a Disease
# 3. See how many have both...

# %% [markdown]
# #### Conflicts with no Disease Xref

# %%
pheno_dis = duped_ids.query('duped_types == @this_dup').copy()

qr = pheno_dis.query('label == "Disease"')
no_d_xref = qr[qr['xrefs'].isnull()]['id'].tolist()

duped_ids.query('id in @no_d_xref')
# Out:
#                id                                         name      label  \
# 601357  Q18054140                                     collapse  Phenotype
# 438089  Q18054140                                     collapse    Disease
# 441581    Q188611                                    hypomania    Disease
# 601483    Q188611                                    hypomania  Phenotype
# 602001    Q322370                                   ablepharon  Phenotype
# 446098    Q322370                                   ablepharon    Disease
# 446188   Q3317827  disability affecting intellectual abilities    Disease
# 602021   Q3317827  disability affecting intellectual abilities  Phenotype
# 446399    Q357522                                      Adipsia    Disease
# 602051    Q357522                                      Adipsia  Phenotype
#
#              xrefs         duped_types
# 601357         NaN  Disease, Phenotype
# 438089         NaN  Disease, Phenotype
# 441581         NaN  Disease, Phenotype
# 601483         NaN  Disease, Phenotype
# 602001  HP:0011224  Disease, Phenotype
# 446098         NaN  Disease, Phenotype
# 446188         NaN  Disease, Phenotype
# 602021  HP:0001249  Disease, Phenotype
# 446399         NaN  Disease, Phenotype
# 602051         NaN  Disease, Phenotype

# %%
this_drop = duped_ids.query('id in @no_d_xref').index.tolist()
drop_idx += this_drop

pheno_dis = pheno_dis.drop(this_drop)

# %%
new_nodes.append(combine_xrefs_and_set_label(duped_ids.loc[this_drop], 'Phenotype'))

# %% [markdown]
# Mostly bad have no xrefs, 2 with phenotypes. I think we can safely merge these to phenotypes

# %% [markdown]
# #### Conflicts with no Pheno Xref

# %%
qr = pheno_dis.query('label == "Phenotype"')
no_p_xref = qr[qr['xrefs'].isnull()]['id'].tolist()

duped_ids.query('id in @no_p_xref')
# Out:
#               id                name      label  \
# 601805  Q2466723  gummatous syphilis  Phenotype
# 444067  Q2466723  gummatous syphilis    Disease
# 602148   Q420915     acroparesthesia  Phenotype
# 446808   Q420915     acroparesthesia    Disease
#
#                                         xrefs         duped_types
# 601805                                    NaN  Disease, Phenotype
# 444067  DOID:DOID:0050584|MONDO:MONDO:0000363  Disease, Phenotype
# 602148                                    NaN  Disease, Phenotype
# 446808           DOID:DOID:6690|UMLS:C1332141  Disease, Phenotype

# %% [markdown]
# gummatous syphilis is a Disease, but the acroparesthesia appears to be a Phenotype

# %%
this_drop = duped_ids.query('id in @no_p_xref').index.tolist()
drop_idx += this_drop

new_nodes.append(duped_ids.loc[this_drop].query('name == "gummatous syphilis" and label == "Disease"'))
new_nodes.append(duped_ids.loc[this_drop].query('name == "acroparesthesia" and label == "Phenotype"'))

pheno_dis = pheno_dis.drop(this_drop)

# %% [markdown]
# #### Now for conflicts with no HPO xref

# %%
qr = pheno_dis.query('label == "Phenotype"').dropna(subset=['xrefs'])
no_hpo_xref = qr[~qr['xrefs'].str.contains('HP:')]['id'].tolist()
duped_ids.query('id in @no_hpo_xref')
# Out:
#                id                name      label  \
# 601081   Q1338684    tension headache  Phenotype
# 437098   Q1338684    tension headache    Disease
# 437642   Q1644260    hearing disorder    Disease
# 601269   Q1644260    hearing disorder  Phenotype
# 601505  Q19000619  urination disorder  Phenotype
# 442708  Q19000619  urination disorder    Disease
# 443632  Q21110016      corneal damage    Disease
# 601597  Q21110016      corneal damage  Phenotype
# 601779   Q2346980     absence seizure  Phenotype
# 443988   Q2346980     absence seizure    Disease
# 601782   Q2365426  Acneiform eruption  Phenotype
# 444003   Q2365426  Acneiform eruption    Disease
# 602239    Q498916             apraxia  Phenotype
# 447311    Q498916             apraxia    Disease
# 602541    Q615363         Torticollis  Phenotype
# 450423    Q615363         Torticollis    Disease
#
#                                                     xrefs         duped_types
# 601081                                       MESH:D018781  Disease, Phenotype
# 437098                                       MESH:D018781  Disease, Phenotype
# 437642  DOID:DOID:12226|MESH:D006311|MONDO:MONDO:00219...  Disease, Phenotype
# 601269                                       MESH:D006311  Disease, Phenotype
# 601505                                       MESH:D014555  Disease, Phenotype
# 442708                         DOID:DOID:578|MESH:D014555  Disease, Phenotype
# 443632                                       MESH:D065306  Disease, Phenotype
# 601597                                       MESH:D065306  Disease, Phenotype
# 601779                                       MESH:D004832  Disease, Phenotype
# 443988                     DOID:DOID:0070309|MESH:D004832  Disease, Phenotype
# 601782                                       MESH:D017486  Disease, Phenotype
# 444003  DOID:DOID:4399|MESH:D017486|MONDO:MONDO:000652...  Disease, Phenotype
# 602239                       MESH:D001072|SNOMED:68345001  Disease, Phenotype
# 447311     DOID:DOID:0060135|MESH:D001072|SNOMED:68345001  Disease, Phenotype
# 602541                                       MESH:D014103  Disease, Phenotype
# 450423                         MESH:D014103|UMLS:C0040485  Disease, Phenotype

# %% [markdown]
# `corneal damage` is a phenotype, remainder can be classified as a disease.

# %%
this_drop = duped_ids.query('id in @no_hpo_xref').index.tolist()
drop_idx += this_drop

new_nodes.append(duped_ids.loc[this_drop].query('name == "corneal damage" and label == "Phenotype"'))
new_nodes.append(combine_xrefs_and_set_label(duped_ids.loc[this_drop].query('name != "corneal damage"'), 'Disease'))

pheno_dis = pheno_dis.drop(this_drop)

# %% [markdown]
# #### Conflicts with no DO xref

# %%
qr = pheno_dis.query('label == "Disease"').dropna(subset=['xrefs'])
no_doid_xref = qr[~qr['xrefs'].str.contains('DOID:')]['id'].tolist()
duped_ids.query('id in @no_doid_xref')
# Out:
#               id           name      label  \
# 600848   Q101971           wart  Phenotype
# 435625   Q101971           wart    Disease
# 600861  Q1036696    hypothermia  Phenotype
# 436504  Q1036696    hypothermia    Disease
# 600873   Q105688        hypoxia  Phenotype
# ...          ...            ...        ...
# 602835   Q970208  liver failure  Phenotype
# 452102   Q974792    albuminuria    Disease
# 602838   Q974792    albuminuria  Phenotype
# 452103   Q974869   leukocytosis    Disease
# 602839   Q974869   leukocytosis  Phenotype
#
#                                           xrefs         duped_types
# 600848                  HP:0200043|MESH:D014860  Disease, Phenotype
# 435625               MESH:D014860|UMLS:C3665596  Disease, Phenotype
# 600861                  HP:0002045|MESH:D007035  Disease, Phenotype
# 436504               MESH:D007035|UMLS:C0020672  Disease, Phenotype
# 600873                  HP:0012418|MESH:D000860  Disease, Phenotype
# ...                                         ...                 ...
# 602835  HP:0001399|MESH:D017093|SNOMED:59927004  Disease, Phenotype
# 452102               MESH:D000419|UMLS:C0001925  Disease, Phenotype
# 602838                  HP:0012592|MESH:D000419  Disease, Phenotype
# 452103               MESH:D007964|UMLS:C0023518  Disease, Phenotype
# 602839                  HP:0001974|MESH:D007964  Disease, Phenotype
#
# [366 rows x 5 columns]

# %% [markdown]
# Lots of examples here... This small smattering looks like Primarily phenotypes...
#
# Lets take a bigger sample to make sure

# %%
duped_ids.query('id in @no_doid_xref').drop_duplicates(subset=['id']).sample(40)
# Out:
#                id                                               name  \
# 601806   Q2470609                                   Wagner's disease
# 451135   Q7113247                                    Ovarian fibroma
# 602165  Q43185102               Hyperkeratosis lenticularis perstans
# 600997    Q117060                                         spasticity
# 449265  Q55784190  glycogen storage disease due to lactate dehydr...
# 451040    Q697117                             spinal disc herniation
# 447592   Q5149292                                       Colpocephaly
# 602636   Q7202556                                         Platybasia
# 601041   Q1268495                                       metrorrhagia
# 602694    Q770843                                        glucagonoma
# 446821  Q42293706                         retinal neovascularization
# 601008  Q11884185                                       nasal cancer
# 602335  Q54973753                                  metatarsal valgus
# 601895   Q2915477                                  folate deficiency
# 448082  Q54875151                                   knee dislocation
# 443300   Q1901516                                      retrognathism
# 451890    Q917069                                     rhabdomyolysis
# 449759  Q55950244  familial congenital nasolacrimal duct obstruction
# 437826  Q17067160                             intraocular hemorrhage
# 448139  Q54927701                          primary headache disorder
# 602266   Q5171111                                corneal perforation
# 452080    Q970208                                      liver failure
# 449275  Q55784285  platelet-activating factor acetylhydrolase def...
# 601078   Q1337441                                  Kostmann syndrome
# 601188   Q1531991                              parkinsonian syndrome
# 437132   Q1347416                                         epispadias
# 601535   Q1996053                               chronic pancreatitis
# 446505   Q3726816                                       epiblepharon
# 602313  Q54911777                     esophageal and gastric varices
# 601210  Q15666414                                   tarsal coalition
# 602611    Q707837                              arteriovenous fistula
# 602043   Q3513620                     junctional ectopic tachycardia
# 602790    Q923164                                 expressive aphasia
# 601743    Q221463                                mesenteric ischemia
# 437063   Q1320276                                        hypovolemia
# 437217    Q141440                                      brain abscess
# 602321  Q54928207                 internal carotid artery dissection
# 437974   Q1753467                                pathologic fracture
# 444340   Q2697787                                           alopecia
# 601282   Q1671598                    intrauterine growth restriction
#
#             label                                              xrefs  \
# 601806  Phenotype                HP:0030673|MESH:C536075|OMIM:143200
# 451135    Disease  MESH:C562391|MONDO:MONDO:0008168|OMIM:166970|O...
# 602165  Phenotype                HP:0007570|MESH:C538377|OMIM:144150
# 600997  Phenotype                            HP:0001257|MESH:D009128
# 449265    Disease  MESH:C563641|MONDO:MONDO:0013587|OMIM:614128|O...
# 451040    Disease  MESH:D007405|OMIM:603932|UMLS:C0021818|UMLS:C1...
# 447592    Disease     MESH:C535973|MONDO:MONDO:0022236|UMLS:C0431384
# 602636  Phenotype                            HP:0002691|MESH:D010985
# 601041  Phenotype                            HP:0100608|MESH:D008796
# 602694  Phenotype           HP:0030404|MESH:D005935|SNOMED:302823005
# 446821    Disease                         MESH:D015861|UMLS:C0035320
# 601008  Phenotype                                         HP:0012720
# 602335  Phenotype                         HP:0010508|MESH:D000070591
# 601895  Phenotype                            HP:0100507|MESH:D005494
# 448082    Disease                         MESH:D031221|UMLS:C0159970
# 443300    Disease                         MESH:D063173|UMLS:C3494422
# 451890    Disease     MESH:D012206|MONDO:MONDO:0005290|UMLS:C0035410
# 449759    Disease  MESH:C566703|MONDO:MONDO:0007871|OMIM:149700|O...
# 437826    Disease                         MESH:D005130|UMLS:C0015402
# 448139    Disease  MESH:D051270|MONDO:MONDO:0017181|ORPHA:276429|...
# 602266  Phenotype                            HP:0100583|MESH:D057112
# 452080    Disease         MESH:D017093|SNOMED:59927004|UMLS:C0085605
# 449275    Disease  MESH:C566640|MONDO:MONDO:0013663|OMIM:614278|U...
# 601078  Phenotype                HP:0005541|MESH:C537592|OMIM:610738
# 601188  Phenotype                            HP:0001300|MESH:D020734
# 437132    Disease  MESH:D004842|MONDO:MONDO:0019759|ORPHA:93928|U...
# 601535  Phenotype                HP:0006280|MESH:D050500|OMIM:167800
# 446505    Disease  MESH:C565051|MONDO:MONDO:0020461|OMIM:131450|O...
# 602313  Phenotype                            HP:0002040|MESH:D004932
# 601210  Phenotype             HP:0008368|MESH:D000070604|OMIM:186850
# 602611  Phenotype           HP:0004947|MESH:D001164|SNOMED:439470001
# 602043  Phenotype                            HP:0011716|MESH:D013613
# 602790  Phenotype                            HP:0002427|MESH:D001039
# 601743  Phenotype                            HP:0030248|MESH:D065666
# 437063    Disease                         MESH:D020896|UMLS:C0546884
# 437217    Disease                         MESH:D001922|UMLS:C0006105
# 602321  Phenotype                            HP:0012159|MESH:D020215
# 437974    Disease                         MESH:D005598|UMLS:C0016663
# 444340    Disease                                       MESH:D000505
# 601282  Phenotype                            HP:0001511|MESH:D005317
#
#                duped_types
# 601806  Disease, Phenotype
# 451135  Disease, Phenotype
# 602165  Disease, Phenotype
# 600997  Disease, Phenotype
# 449265  Disease, Phenotype
# 451040  Disease, Phenotype
# 447592  Disease, Phenotype
# 602636  Disease, Phenotype
# 601041  Disease, Phenotype
# 602694  Disease, Phenotype
# 446821  Disease, Phenotype
# 601008  Disease, Phenotype
# 602335  Disease, Phenotype
# 601895  Disease, Phenotype
# 448082  Disease, Phenotype
# 443300  Disease, Phenotype
# 451890  Disease, Phenotype
# 449759  Disease, Phenotype
# 437826  Disease, Phenotype
# 448139  Disease, Phenotype
# 602266  Disease, Phenotype
# 452080  Disease, Phenotype
# 449275  Disease, Phenotype
# 601078  Disease, Phenotype
# 601188  Disease, Phenotype
# 437132  Disease, Phenotype
# 601535  Disease, Phenotype
# 446505  Disease, Phenotype
# 602313  Disease, Phenotype
# 601210  Disease, Phenotype
# 602611  Disease, Phenotype
# 602043  Disease, Phenotype
# 602790  Disease, Phenotype
# 601743  Disease, Phenotype
# 437063  Disease, Phenotype
# 437217  Disease, Phenotype
# 602321  Disease, Phenotype
# 437974  Disease, Phenotype
# 444340  Disease, Phenotype
# 601282  Disease, Phenotype

# %% [markdown]
# Lots of HPO Xrefs on these, most look like phenotypes, so we will coerce them all to phenotypes, while maintaining the original Xref

# %%
this_drop = duped_ids.query('id in @no_doid_xref').index.tolist()
drop_idx += this_drop

new_nodes.append(combine_xrefs_and_set_label(duped_ids.loc[this_drop], 'Phenotype'))

pheno_dis = pheno_dis.drop(this_drop)

# %% [markdown]
# What's left should have both DO and HPO xref identifiers

# %%
pheno_dis
# Out:
#                 id                             name      label  \
# 600847    Q1016605                 Burkitt lymphoma  Phenotype
# 435620    Q1016605                 Burkitt lymphoma    Disease
# 600851  Q102293266  calcium oxalate nephrolithiasis  Phenotype
# 435671  Q102293266  calcium oxalate nephrolithiasis    Disease
# 436481    Q1027995                 pyloric stenosis    Disease
# ...            ...                              ...        ...
# 602845     Q979168                   cerebral edema  Phenotype
# 602847     Q994859                   homocystinuria  Phenotype
# 452132     Q994859                   homocystinuria    Disease
# 602848     Q994942                          bruxism  Phenotype
# 452133     Q994942                          bruxism    Disease
#
#                                                     xrefs         duped_types
# 600847                HP:0030080|MESH:D002051|OMIM:113970  Disease, Phenotype
# 435620  DOID:DOID:8584|MESH:D002051|OMIM:113970|ORPHA:...  Disease, Phenotype
# 600851                                         HP:0008672  Disease, Phenotype
# 435671                                  DOID:DOID:0080652  Disease, Phenotype
# 436481         DOID:DOID:12639|MESH:D011707|UMLS:C0034194  Disease, Phenotype
# ...                                                   ...                 ...
# 602845                            HP:0002181|MESH:D001929  Disease, Phenotype
# 602847  HP:0002156|MESH:D006712|OMIM:236200|OMIM:23625...  Disease, Phenotype
# 452132  DOID:DOID:9263|MESH:D006712|MONDO:MONDO:000473...  Disease, Phenotype
# 602848                            HP:0003763|MESH:D002012  Disease, Phenotype
# 452133  DOID:DOID:2846|MESH:D002012|MONDO:MONDO:000244...  Disease, Phenotype
#
# [1864 rows x 5 columns]

# %% [markdown]
# Still 900 confilcts... all we can do here is split the concepts.
#
# We'll keep the cannonical wikidata item as a Disease, and make new phenotypes with the HPO Xrefs...

# %%
pheno_nodes = get_curi_xrefs(pheno_dis.query('label == "Phenotype"'), 'HP')
pheno_nodes = pheno_nodes.merge(pheno_dis.query('label == "Phenotype"'), how='left', on='id', suffixes=('', '_old'))
xrefs = pheno_nodes['xrefs_old']

# Remove the hpo xref from the nodes
xrefs = split_col(xrefs, '|').apply(lambda x: [r for r in x if not r.startswith('HP:')]).apply(lambda x: '|'.join(x))

add_nodes = xrefs_to_new_nodes(pheno_nodes)
add_nodes['xrefs'] = xrefs

# Add the Pheno and disease nodes
new_nodes.append(add_nodes.replace('', float('nan')))
new_nodes.append(pheno_dis.query('label == "Disease"'))

# Add the Disease to pheno edges
new_edges.append(xrefs_to_new_edges(pheno_nodes, 'id', 'xrefs', 'presents'))

# %%
drop_idx += pheno_dis.index.tolist()

# %% [markdown]
# ## Putting it all back together

# %%
nodes = nodes.drop(drop_idx)
nodes = pd.concat([nodes]+new_nodes, sort=False, ignore_index=True).drop('duped_types', axis=1)

nodes
# Out:
#                id                    name    label  \
# 0        Q1010102            Bunyaviridae    Taxon
# 1        Q1026758           Caliciviridae    Taxon
# 2       Q10457821  Conidiobolus coronatus    Taxon
# 3       Q10462705  Cryptostroma corticale    Taxon
# 4       Q10584816   Microsporum distortum    Taxon
# ...           ...                     ...      ...
# 737016    Q976388          acute leukemia  Disease
# 737017    Q977787      gallbladder cancer  Disease
# 737018    Q979168          cerebral edema  Disease
# 737019    Q994859          homocystinuria  Disease
# 737020    Q994942                 bruxism  Disease
#
#                                                     xrefs
# 0                                                     NaN
# 1                                         NCBITaxon:11974
# 2                                         NCBITaxon:34488
# 3                                       NCBITaxon:1463975
# 4                                        NCBITaxon:101202
# ...                                                   ...
# 737016  DOID:DOID:12603|MESH:C564112|MONDO:MONDO:00106...
# 737017  DOID:DOID:3121|MONDO:MONDO:0005411|UMLS:C00169...
# 737018  DOID:DOID:4724|MESH:D001929|MONDO:MONDO:000668...
# 737019  DOID:DOID:9263|MESH:D006712|MONDO:MONDO:000473...
# 737020  DOID:DOID:2846|MESH:D002012|MONDO:MONDO:000244...
#
# [737021 rows x 4 columns]

# %%
edges = pd.concat([edges]+new_edges, sort=False, ignore_index=True)

# %%
edges
# Out:
#           start_id      end_id      type      dsrc_type comp_type
# 0         Q7331932    Q5459411    causes  crowd_sourced       NaN
# 1         Q2305662   Q55009413    causes  crowd_sourced       NaN
# 2         Q9094469   Q55009678    causes  crowd_sourced       NaN
# 3        Q18822400   Q55009464    causes  crowd_sourced       NaN
# 4         Q1138287   Q18966421    causes  crowd_sourced       NaN
# ...            ...         ...       ...            ...       ...
# 3880457    Q976388  HP:0002488  presents       computed     split
# 3880458    Q977787  HP:0100575  presents       computed     split
# 3880459    Q979168  HP:0002181  presents       computed     split
# 3880460    Q994859  HP:0002156  presents       computed     split
# 3880461    Q994942  HP:0003763  presents       computed     split
#
# [3880462 rows x 5 columns]

# %% [markdown]
# ## Cleaning Up Edges
#
# Some of the Edge Queryies we were less specific about how we defined node types... So we may have some IDs that don't appear in any of the nodes. We need to remove these.

# %%
print('{:,}'.format(len(edges)))

node_ids = nodes['id'].unique()
edges = edges.query('start_id in @node_ids and end_id in @node_ids')

print('{:,}'.format(len(edges)))
# Out:
# 3,880,462
# 1,484,147

# %%
edges = edges.drop_duplicates(subset=['start_id', 'end_id', 'type'])
print('{:,}'.format(len(edges)))
# Out:
# 1,480,518

# %%
count_plot_h(edges['dsrc_type'])

# %%
count_plot_h(edges['comp_type'])

# %%
count_plot_h(edges['type'])

# %%
count_plot_h(nodes['label'])

# %%
combo = combine_nodes_and_edges(nodes, edges)

# %%
meta_edges = combo['start_label'] + '_' + combo['type'] + '_' + combo['end_label']
meta_edges.nunique()
# Out:
# 47

# %%
count_plot_h(meta_edges.value_counts().head(10))

# %%
count_plot_h(meta_edges.value_counts().head(20).tail(10))

# %%
count_plot_h(meta_edges.value_counts().head(30).tail(10))

# %%
count_plot_h(meta_edges.value_counts().head(40).tail(10))

# %%
count_plot_h(meta_edges.value_counts().tail(6))

# %% [markdown]
# Many of the low count metaedges are either mistakes, or otherwise useless noisy edges:
#
# Compound to protein edges are ok as they will later be changed to simplied semmantics:
#
# One other should be examined:
#
# - Disease Presents Diseases
#
# This edge is of diseases that are also likely phenotypes, so we should have the proper phenotype in place instead of the disease
#
# For now we will drop these edges...

# %%
drop_me = ['Protein_enables_Biological Process', 'Phenotype_subclass_of_Phenotype', 'Phenotype_subclass_of_Disease',
          'Disease_subclass_of_Phenotype', 'Phenotype_presents_Disease', 'Protein_involved_in_Molecular Function',
          'Cellular Component_subclass_of_Cellular Component', 'Phenotype_presents_Phenotype', 
          'Protein_agonist_Protein', 'Protein_involved_in_Cellular Component', 'Protein_involved_in_Disease',
          'Gene_associated_with_Gene', 'Gene_subclass_of_Gene', 'Disease_causes_Disease']

# %%
new_drop_index = meta_edges.rename('me').to_frame().query('me in @drop_me').index
len(new_drop_index)
# Out:
# 897

# %% [markdown]
# ### Now examine the Likely Disease Phenotype Edges...

# %%
dis_pheno_idx = combo.query('start_label == "Disease" and end_label == "Disease" and type != "subclass_of"').index

# %%
combo.loc[dis_pheno_idx].head(20)
# Out:
#          start_id    end_id      type      dsrc_type comp_type  \
# 211       Q184627  Q1223924    causes  crowd_sourced       NaN
# 3830985    Q62736   Q170990  presents  crowd_sourced       NaN
# 3830987   Q152401   Q189956  presents  crowd_sourced       NaN
# 3830988   Q155098   Q186235  presents  crowd_sourced       NaN
# 3830989   Q156050   Q170990  presents  crowd_sourced       NaN
# 3830993   Q201989   Q170990  presents  crowd_sourced       NaN
# 3830994   Q201989   Q186235  presents  crowd_sourced       NaN
# 3830996   Q559082   Q170990  presents  crowd_sourced       NaN
# 3830999   Q649558   Q186235  presents  crowd_sourced       NaN
# 3831001   Q706845   Q186235  presents  crowd_sourced       NaN
# 3831003   Q868137   Q170990  presents  crowd_sourced       NaN
# 3831004   Q911427   Q170990  presents  crowd_sourced       NaN
# 3831005   Q911427   Q189956  presents  crowd_sourced       NaN
# 3831006   Q924421   Q170990  presents  crowd_sourced       NaN
# 3831007  Q1035319   Q170990  presents  crowd_sourced       NaN
# 3831008  Q1048101   Q189956  presents  crowd_sourced       NaN
# 3831011  Q1345113   Q186235  presents  crowd_sourced       NaN
# 3831017  Q2360849   Q186235  presents  crowd_sourced       NaN
# 3831019  Q3495854   Q170990  presents  crowd_sourced       NaN
# 3831021  Q3798547   Q170990  presents  crowd_sourced       NaN
#
#                              start_name             end_name start_label  \
# 211      human papillomavirus infection       papillomatosis     Disease
# 3830985                  osteoarthritis            arthritis     Disease
# 3830987          foot-and-mouth disease  aphthous stomatitis     Disease
# 3830988                   leptospirosis          myocarditis     Disease
# 3830989                     brucellosis            arthritis     Disease
# 3830993                    Lyme disease            arthritis     Disease
# 3830994                    Lyme disease          myocarditis     Disease
# 3830996               chondrocalcinosis            arthritis     Disease
# 3830999                  Chagas disease          myocarditis     Disease
# 3831001                     Lassa fever          myocarditis     Disease
# 3831003              coccidioidomycosis            arthritis     Disease
# 3831004                Behçet's disease            arthritis     Disease
# 3831005                Behçet's disease  aphthous stomatitis     Disease
# 3831006                septic arthritis            arthritis     Disease
# 3831007       Henoch-Schoenlein purpura            arthritis     Disease
# 3831008                  rickettsialpox  aphthous stomatitis     Disease
# 3831011                    toxocariasis          myocarditis     Disease
# 3831017                strongyloidiasis          myocarditis     Disease
# 3831019          palindromic rheumatism            arthritis     Disease
# 3831021                 Haverhill fever            arthritis     Disease
#
#         end_label
# 211       Disease
# 3830985   Disease
# 3830987   Disease
# 3830988   Disease
# 3830989   Disease
# 3830993   Disease
# 3830994   Disease
# 3830996   Disease
# 3830999   Disease
# 3831001   Disease
# 3831003   Disease
# 3831004   Disease
# 3831005   Disease
# 3831006   Disease
# 3831007   Disease
# 3831008   Disease
# 3831011   Disease
# 3831017   Disease
# 3831019   Disease
# 3831021   Disease

# %%
likely_phenos = combo.loc[dis_pheno_idx]['end_id']

# %%
pheno_names = nodes.query('id in @likely_phenos')['name']
pheno_ids = nodes.query('name in @pheno_names and label == "Phenotype"')['id']
pheno_map = combo.query('start_label == "Disease" and end_id in @pheno_ids').set_index('start_id')['end_id'].to_dict()

# %%
edges.loc[dis_pheno_idx, 'end_id'] = edges.loc[dis_pheno_idx]['end_id'].map(pheno_map)

# %%
edges.loc[dis_pheno_idx]
# Out:
#           start_id      end_id      type      dsrc_type comp_type
# 211        Q184627         NaN    causes  crowd_sourced       NaN
# 3830985     Q62736  HP:0001369  presents  crowd_sourced       NaN
# 3830987    Q152401  HP:0011107  presents  crowd_sourced       NaN
# 3830988    Q155098  HP:0012819  presents  crowd_sourced       NaN
# 3830989    Q156050  HP:0001369  presents  crowd_sourced       NaN
# ...            ...         ...       ...            ...       ...
# 3833080   Q3540887  HP:0000717  presents  crowd_sourced       NaN
# 3833082  Q56244339  HP:0002014  presents  crowd_sourced       NaN
# 3833085    Q408089  HP:0000112  presents  crowd_sourced       NaN
# 3833097   Q3153686  HP:0000112  presents  crowd_sourced       NaN
# 3833102   Q7688951  HP:0001629  presents  crowd_sourced       NaN
#
# [589 rows x 5 columns]

# %%
edges = edges.drop(new_drop_index)
edges = edges.dropna(subset=['end_id'])

# %%
combo = combine_nodes_and_edges(nodes, edges)

# %%
meta_edges = combo['start_label'] + '_' + combo['type'] + '_' + combo['end_label']
meta_edges.nunique()
# Out:
# 33

# %%
plt.figure(figsize=(8,12))
count_plot_h(meta_edges)

# %% [markdown]
# ## Save out Resultant Edges

# %%
out_dir = Path('../results/')

out_dir.mkdir(parents=True, exist_ok=True)

nodes.to_csv(out_dir.joinpath('01c_nodes.csv'), index=False)
edges.to_csv(out_dir.joinpath('01c_edges.csv'), index=False)
